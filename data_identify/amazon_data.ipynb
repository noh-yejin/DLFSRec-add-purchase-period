# %% [markdown]
# ## Amazon data load

# %%
import gzip
import json
import pandas as pd
from collections import defaultdict

user_reviews= defaultdict(list)

def parse_jsonl_gz_file(file_path):
    user_id_list = []
    asin_list = []
    timestamp_list = []
    
    with gzip.open(file_path, 'rt', encoding='utf-8') as f:
        for line in f:
            data = json.loads(line.strip())
            user_id_list.append(data['reviewerID'])
            asin_list.append(data['asin'])
            timestamp_list.append(data['unixReviewTime'])
    
    df = pd.DataFrame({
        'user_id': user_id_list,
        'asin': asin_list,
        'timestamp': timestamp_list
    })
    
    return df

file_path = 'data/Electronics_5.json.gz'

df = parse_jsonl_gz_file(file_path)

print(df.head())
# Out:
#           user_id        asin   timestamp
# 0   AAP7PPBU72QFM  0151004714   937612800
# 1  A2E168DTVGE6SV  0151004714  1382486400
# 2  A1ER5AYS3FQ9O3  0151004714  1220313600
# 3  A1T17LMQABMBN5  0151004714   968025600
# 4  A3QHJ0FXK33OBE  0151004714   949622400

# %%
duplicate_rows = df.duplicated(keep=False)
df_unique = df[~duplicate_rows]

# %%
# df_unique['user_id'],_ = pd.factorize(df['user_id'])
# df['asin'],_ = pd.factorize(df['asin'])  
# df = df.drop_duplicates(subset=['user_id', 'asin', 'timestamp']) # 중복 데이터 제거

gropuby_df= df_unique.groupby('user_id')['asin'].apply(list).reset_index()
gropuby_df
# Out:
#                      user_id  \
# 0       A0001528BGUBOEVR6T5U
# 1       A0003214FKMKJE0PCW3D
# 2       A0008898NGEXICE0F146
# 3       A00101847G3FJTWYGNQA
# 4       A0014476IZYE2N3XTK4K
# ...                      ...
# 728479         AZZYW4YOE1B6E
# 728480         AZZZ3LGTCGUZF
# 728481         AZZZF5PSCPILV
# 728482         AZZZRS1YZ8HVP
# 728483         AZZZU3P1UQZ0C
#
#                                                      asin
# 0        [B0055Q2VS8, B005XU7OL0, B007DJTBVK, B008FKDK2M]
# 1       [B000P1O73A, B004XJ6R0Q, B004XVN1V2, B00BFO14W...
# 2       [B00005LEOO, B00009XVCZ, B009NVXGAI, B00KOUIC0...
# 3       [B0002JFNP6, B00453R808, B004WJRBUW, B005F778J...
# 4                    [B00A66XB54, B00DIF2BO2, B00L9K3MY6]
# ...                                                   ...
# 728479  [B000CKVOOY, B000EH0NLK, B000OOYECC, B001AK049...
# 728480  [B004M8SBCK, B00EI4OIGQ, B017ANBP9Y, B01CG4C7F...
# 728481  [B00JH23QMQ, B00RL9U878, B0123UHBBU, B01DXVKQE...
# 728482               [B001CJOLBW, B00EZ9XKCM, B01CVOLKKQ]
# 728483  [B0007NWL70, B00092DZ6U, B007PUMCWC, B00ESW9SZ...
#
# [728484 rows x 2 columns]

# %%
# 중복된 항목을 추출하여 새로운 컬럼에 저장하는 함수 정의
def extract_duplicates(items):
    duplicate_items = []
    for item in items:
        if items.count(item) > 1 and item not in duplicate_items:
            duplicate_items.append(item)
    return duplicate_items

# 새로운 컬럼에 중복된 항목 저장
gropuby_df['duplicated_items'] = gropuby_df['asin'].apply(extract_duplicates)

print(gropuby_df)
# Out:
#                      user_id  \
# 0       A0001528BGUBOEVR6T5U
# 1       A0003214FKMKJE0PCW3D
# 2       A0008898NGEXICE0F146
# 3       A00101847G3FJTWYGNQA
# 4       A0014476IZYE2N3XTK4K
# ...                      ...
# 728479         AZZYW4YOE1B6E
# 728480         AZZZ3LGTCGUZF
# 728481         AZZZF5PSCPILV
# 728482         AZZZRS1YZ8HVP
# 728483         AZZZU3P1UQZ0C
#
#                                                      asin duplicated_items
# 0        [B0055Q2VS8, B005XU7OL0, B007DJTBVK, B008FKDK2M]               []
# 1       [B000P1O73A, B004XJ6R0Q, B004XVN1V2, B00BFO14W...               []
# 2       [B00005LEOO, B00009XVCZ, B009NVXGAI, B00KOUIC0...               []
# 3       [B0002JFNP6, B00453R808, B004WJRBUW, B005F778J...               []
# 4                    [B00A66XB54, B00DIF2BO2, B00L9K3MY6]               []
# ...                                                   ...              ...
# 728479  [B000CKVOOY, B000EH0NLK, B000OOYECC, B001AK049...               []
# 728480  [B004M8SBCK, B00EI4OIGQ, B017ANBP9Y, B01CG4C7F...               []
# 728481  [B00JH23QMQ, B00RL9U878, B0123UHBBU, B01DXVKQE...               []
# 728482               [B001CJOLBW, B00EZ9XKCM, B01CVOLKKQ]               []
# 728483  [B0007NWL70, B00092DZ6U, B007PUMCWC, B00ESW9SZ...               []
#
# [728484 rows x 3 columns]

# %%
len(gropuby_df[gropuby_df['duplicated_items'].apply(lambda x:len(x))>=1])  # 재구매 user 수
# Out:
# 7780

# %%
7780/728484*100
# Out:
# 1.0679712938101593

# %%
len(df['asin'].unique())
# Out:
# 160052

# %%
# 중복을 제거할 집합(set) 생성
unique_items = set()

# 데이터프레임의 duplicated_items 컬럼을 순회하면서 중복 없이 원소 추가
for row in gropuby_df['duplicated_items']:
    unique_items.update(row)

# 중복 없이 추가된 원소들을 리스트로 변환
unique_items_list = list(unique_items)

# %%
len(unique_items_list)
# Out:
# 3645

# %%
3645/160052*100
# Out:
# 2.2773848499237745

# %% [markdown]
# ## 범위 확장 (동일 item-> 브랜드 or 카테고리)
# - 둘 중에 더 구별이 잘 되는 범주로 선택

# %%
import gzip
import json
import pandas as pd

def parse(path):
    with gzip.open(path, 'rb') as f:
        for line in f:
            yield json.loads(line)

def get_items_meta(meta_path):
    item2price = {}
    item2category = {}
    item2brand = {}


    for l in parse(meta_path):
        asin = l['asin']
        item2category[asin] = l['category']
        item2price[asin] = l['price'][1:] if 'price' in l else 0.0
        item2brand[asin] = l['brand'] if 'brand' in l else ''

    items_meta = {
        'item2price': item2price,
        'item2category': item2category,
        'item2brand': item2brand
    }

    return items_meta


file_path = 'data/Grocery_and_Gourmet_Food/meta_Grocery_and_Gourmet_Food.json.gz'
items_meta=get_items_meta(file_path)
items_meta
# Out:
# {'item2price': {'0681727810': '41.91',
#   '0853347867': '',
#   '1888861118': '29.95',
#   '1888861517': '11.45',
#   '1888861614': '15.00',
#   '1888861533': '10.99',
#   '1888861339': '12.91',
#   '1888861355': '12.99',
#   '188886155X': '10.99',
#   '1888861207': '11.00',
#   '4639725043': '12.46',
#   '4639725183': '12.98',
#   '4858582000': '25.93',
#   '5236363640': '24.99',
#   '541255556X': '18.99',
#   '5463213682': '29.90',
#   '5478541265': '',
#   '5643467860': '',
#   '6040343958': '',
#   '6040763906': '',
#   '6163058011': '49.98',
#   '618205610X': '9.28',
#   '6182055979': '',
#   '6182056010': '15.20',
#   '7107272160': '107.99',
#   '7531848279': '52.99',
#   '7656543546': '20.30',
#   '7621000880': '',
#   '7656453768': '',
#   '7656453458': '',
#   '7621915358': '',
#   '7800648702': '',
#   '8166679507': '',
#   '8557758987': '10.99',
#   '9177121805': 'a-box-inner{background-color:#fff}#alohaBuyBoxWidget .selected{background-color:#fffbf3;border-color:#e77600;box-shadow:0 0 3px rgba(228,121,17,.5)}#alohaBuyBoxWidget .contract-not-available{color:gray}#aloha-cart-popover .aloha-cart{height:auto;overflow:hidden}#aloha-cart-popover #aloha-cartInfo{float:left}#aloha-cart-popover #aloha-cart-details{float:right;margin-top:1em}#aloha-cart-popover .deviceContainer{width:160px;float:left;padding-right:10px;border-right:1px solid #ddd}#aloha-cart-popover li:last-child{border-right:0}#aloha-cart-popover .aloha-device-title{height:3em;overflow:hidden}#aloha-cart-popover .aloha-thumbnail-container{height:100px;margin-bottom:1em;text-align:center}#aloha-cart-popover .aloha-price-container{text-align:center}#aloha-cart-popover .aloha-thumbnail-container img{height:inherit}#aloha-cart-popover .aloha-cart{border-top:1px solid #ddd;border-bottom:1px solid #ddd}#aloha-cart-popover #aloha-cart-info{margin-right:0}#alohaBuyBoxWidget .without-contract-subheading{margin-right:0}#aloha-bb-help-nodes .aloha-bb-contract-term-heading{color:gray;font-family:arial;margin-top:.5em;text-align:center;height:.7em;border-bottom:1px solid gray;margin-bottom:1.6em}#aloha-bb-help-nodes .aloha-bb-contract-term-heading span{background-color:#fff;padding:0 10px 0 10px}#alohaAvailabilityUS_feature_div .availability a{text-decoration:none}#alohaPricingWidget a{text-decoration:none}#alohaAvailabilityUS_feature_div .availability{margin-top:-4px;margin-bottom:0}#alohaBuyBoxWidget .select-transaction-alert .a-icon-alert{top:18px;left:3px}#alohaBuyBoxWidget .select-transaction-alert .a-alert-container{padding-left:39px;width:290px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .contract-term-heading a{text-decoration:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .annual-contract-box .a-icon-popover{display:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .annual-contract-box{cursor:pointer;cursor:hand}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .aloha-buybox-price{font-size:15px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget #linkOffSection a{text-decoration:none}#alohaBuyBoxUS_feature_div .lockedUsedBuyboxContainer{padding-left:3.5%}#alohaBuyBoxUS_feature_div .alohaBuyboxUtilsNoWrap{white-space:nowrap}.hidden{display:none}.simo-no-padding{padding:0}.carrier-reviews-cell{padding-left:10px}.carrier-reviews-bordered-cell{border:1px dotted #ccc}.carrier-reviews-selected-cell{background-color:#ffd}#aloha-carrier-compatibility-modal-table-description{margin-top:10px;margin-bottom:14px}.aloha-carrier-compatibility-sortable-header.carrier{min-width:97px}.aloha-carrier-compatibility-sortable-header.compatibility{min-width:156px}.aloha-carrier-compatibility-sortable-header div{float:left}.aloha-carrier-compatibility-sortable-header i.a-icon{margin-left:10px;margin-top:4px}#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes th:nth-child(2n),.aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes td:nth-child(2n){background-color:transparent}.aloha-carrier-compatibility-column-gray{background-color:#f6f6f6}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text,.aloha-carrier-compatibility-modal-table-row .carrier-name,.aloha-carrier-compatibility-modal-table-row .carrier-rating-summary{min-height:27px;display:inline-block;cursor:default}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text:first-line,.aloha-carrier-compatibility-modal-table-row .carrier-name:first-line,.aloha-carrier-comp ...
#   '9177121791': '',
#   '9178894018': 'a-box-inner{background-color:#fff}#alohaBuyBoxWidget .selected{background-color:#fffbf3;border-color:#e77600;box-shadow:0 0 3px rgba(228,121,17,.5)}#alohaBuyBoxWidget .contract-not-available{color:gray}#aloha-cart-popover .aloha-cart{height:auto;overflow:hidden}#aloha-cart-popover #aloha-cartInfo{float:left}#aloha-cart-popover #aloha-cart-details{float:right;margin-top:1em}#aloha-cart-popover .deviceContainer{width:160px;float:left;padding-right:10px;border-right:1px solid #ddd}#aloha-cart-popover li:last-child{border-right:0}#aloha-cart-popover .aloha-device-title{height:3em;overflow:hidden}#aloha-cart-popover .aloha-thumbnail-container{height:100px;margin-bottom:1em;text-align:center}#aloha-cart-popover .aloha-price-container{text-align:center}#aloha-cart-popover .aloha-thumbnail-container img{height:inherit}#aloha-cart-popover .aloha-cart{border-top:1px solid #ddd;border-bottom:1px solid #ddd}#aloha-cart-popover #aloha-cart-info{margin-right:0}#alohaBuyBoxWidget .without-contract-subheading{margin-right:0}#aloha-bb-help-nodes .aloha-bb-contract-term-heading{color:gray;font-family:arial;margin-top:.5em;text-align:center;height:.7em;border-bottom:1px solid gray;margin-bottom:1.6em}#aloha-bb-help-nodes .aloha-bb-contract-term-heading span{background-color:#fff;padding:0 10px 0 10px}#alohaAvailabilityUS_feature_div .availability a{text-decoration:none}#alohaPricingWidget a{text-decoration:none}#alohaAvailabilityUS_feature_div .availability{margin-top:-4px;margin-bottom:0}#alohaBuyBoxWidget .select-transaction-alert .a-icon-alert{top:18px;left:3px}#alohaBuyBoxWidget .select-transaction-alert .a-alert-container{padding-left:39px;width:290px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .contract-term-heading a{text-decoration:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .annual-contract-box .a-icon-popover{display:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .annual-contract-box{cursor:pointer;cursor:hand}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .aloha-buybox-price{font-size:15px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget #linkOffSection a{text-decoration:none}#alohaBuyBoxUS_feature_div .lockedUsedBuyboxContainer{padding-left:3.5%}#alohaBuyBoxUS_feature_div .alohaBuyboxUtilsNoWrap{white-space:nowrap}.hidden{display:none}.simo-no-padding{padding:0}.carrier-reviews-cell{padding-left:10px}.carrier-reviews-bordered-cell{border:1px dotted #ccc}.carrier-reviews-selected-cell{background-color:#ffd}#aloha-carrier-compatibility-modal-table-description{margin-top:10px;margin-bottom:14px}.aloha-carrier-compatibility-sortable-header.carrier{min-width:97px}.aloha-carrier-compatibility-sortable-header.compatibility{min-width:156px}.aloha-carrier-compatibility-sortable-header div{float:left}.aloha-carrier-compatibility-sortable-header i.a-icon{margin-left:10px;margin-top:4px}#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes th:nth-child(2n),.aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes td:nth-child(2n){background-color:transparent}.aloha-carrier-compatibility-column-gray{background-color:#f6f6f6}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text,.aloha-carrier-compatibility-modal-table-row .carrier-name,.aloha-carrier-compatibility-modal-table-row .carrier-rating-summary{min-height:27px;display:inline-block;cursor:default}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text:first-line,.aloha-carrier-compatibility-modal-table-row .carrier-name:first-line,.aloha-carrier-comp ...
#   '9178902568': '',
#   '9178894999': '',
#   '9178915155': '',
#   '9552900026': 'a-box-inner{background-color:#fff}#alohaBuyBoxWidget .selected{background-color:#fffbf3;border-color:#e77600;box-shadow:0 0 3px rgba(228,121,17,.5)}#alohaBuyBoxWidget .contract-not-available{color:gray}#aloha-cart-popover .aloha-cart{height:auto;overflow:hidden}#aloha-cart-popover #aloha-cartInfo{float:left}#aloha-cart-popover #aloha-cart-details{float:right;margin-top:1em}#aloha-cart-popover .deviceContainer{width:160px;float:left;padding-right:10px;border-right:1px solid #ddd}#aloha-cart-popover li:last-child{border-right:0}#aloha-cart-popover .aloha-device-title{height:3em;overflow:hidden}#aloha-cart-popover .aloha-thumbnail-container{height:100px;margin-bottom:1em;text-align:center}#aloha-cart-popover .aloha-price-container{text-align:center}#aloha-cart-popover .aloha-thumbnail-container img{height:inherit}#aloha-cart-popover .aloha-cart{border-top:1px solid #ddd;border-bottom:1px solid #ddd}#aloha-cart-popover #aloha-cart-info{margin-right:0}#alohaBuyBoxWidget .without-contract-subheading{margin-right:0}#aloha-bb-help-nodes .aloha-bb-contract-term-heading{color:gray;font-family:arial;margin-top:.5em;text-align:center;height:.7em;border-bottom:1px solid gray;margin-bottom:1.6em}#aloha-bb-help-nodes .aloha-bb-contract-term-heading span{background-color:#fff;padding:0 10px 0 10px}#alohaAvailabilityUS_feature_div .availability a{text-decoration:none}#alohaPricingWidget a{text-decoration:none}#alohaAvailabilityUS_feature_div .availability{margin-top:-4px;margin-bottom:0}#alohaBuyBoxWidget .select-transaction-alert .a-icon-alert{top:18px;left:3px}#alohaBuyBoxWidget .select-transaction-alert .a-alert-container{padding-left:39px;width:290px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .contract-term-heading a{text-decoration:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .annual-contract-box .a-icon-popover{display:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .annual-contract-box{cursor:pointer;cursor:hand}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .aloha-buybox-price{font-size:15px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget #linkOffSection a{text-decoration:none}#alohaBuyBoxUS_feature_div .lockedUsedBuyboxContainer{padding-left:3.5%}#alohaBuyBoxUS_feature_div .alohaBuyboxUtilsNoWrap{white-space:nowrap}.hidden{display:none}.simo-no-padding{padding:0}.carrier-reviews-cell{padding-left:10px}.carrier-reviews-bordered-cell{border:1px dotted #ccc}.carrier-reviews-selected-cell{background-color:#ffd}#aloha-carrier-compatibility-modal-table-description{margin-top:10px;margin-bottom:14px}.aloha-carrier-compatibility-sortable-header.carrier{min-width:97px}.aloha-carrier-compatibility-sortable-header.compatibility{min-width:156px}.aloha-carrier-compatibility-sortable-header div{float:left}.aloha-carrier-compatibility-sortable-header i.a-icon{margin-left:10px;margin-top:4px}#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes th:nth-child(2n),.aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes td:nth-child(2n){background-color:transparent}.aloha-carrier-compatibility-column-gray{background-color:#f6f6f6}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text,.aloha-carrier-compatibility-modal-table-row .carrier-name,.aloha-carrier-compatibility-modal-table-row .carrier-rating-summary{min-height:27px;display:inline-block;cursor:default}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text:first-line,.aloha-carrier-compatibility-modal-table-row .carrier-name:first-line,.aloha-carrier-comp ...
#   '9717894531': 'a-box-inner{background-color:#fff}#alohaBuyBoxWidget .selected{background-color:#fffbf3;border-color:#e77600;box-shadow:0 0 3px rgba(228,121,17,.5)}#alohaBuyBoxWidget .contract-not-available{color:gray}#aloha-cart-popover .aloha-cart{height:auto;overflow:hidden}#aloha-cart-popover #aloha-cartInfo{float:left}#aloha-cart-popover #aloha-cart-details{float:right;margin-top:1em}#aloha-cart-popover .deviceContainer{width:160px;float:left;padding-right:10px;border-right:1px solid #ddd}#aloha-cart-popover li:last-child{border-right:0}#aloha-cart-popover .aloha-device-title{height:3em;overflow:hidden}#aloha-cart-popover .aloha-thumbnail-container{height:100px;margin-bottom:1em;text-align:center}#aloha-cart-popover .aloha-price-container{text-align:center}#aloha-cart-popover .aloha-thumbnail-container img{height:inherit}#aloha-cart-popover .aloha-cart{border-top:1px solid #ddd;border-bottom:1px solid #ddd}#aloha-cart-popover #aloha-cart-info{margin-right:0}#alohaBuyBoxWidget .without-contract-subheading{margin-right:0}#aloha-bb-help-nodes .aloha-bb-contract-term-heading{color:gray;font-family:arial;margin-top:.5em;text-align:center;height:.7em;border-bottom:1px solid gray;margin-bottom:1.6em}#aloha-bb-help-nodes .aloha-bb-contract-term-heading span{background-color:#fff;padding:0 10px 0 10px}#alohaAvailabilityUS_feature_div .availability a{text-decoration:none}#alohaPricingWidget a{text-decoration:none}#alohaAvailabilityUS_feature_div .availability{margin-top:-4px;margin-bottom:0}#alohaBuyBoxWidget .select-transaction-alert .a-icon-alert{top:18px;left:3px}#alohaBuyBoxWidget .select-transaction-alert .a-alert-container{padding-left:39px;width:290px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .contract-term-heading a{text-decoration:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .annual-contract-box .a-icon-popover{display:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .annual-contract-box{cursor:pointer;cursor:hand}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .aloha-buybox-price{font-size:15px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget #linkOffSection a{text-decoration:none}#alohaBuyBoxUS_feature_div .lockedUsedBuyboxContainer{padding-left:3.5%}#alohaBuyBoxUS_feature_div .alohaBuyboxUtilsNoWrap{white-space:nowrap}.hidden{display:none}.simo-no-padding{padding:0}.carrier-reviews-cell{padding-left:10px}.carrier-reviews-bordered-cell{border:1px dotted #ccc}.carrier-reviews-selected-cell{background-color:#ffd}#aloha-carrier-compatibility-modal-table-description{margin-top:10px;margin-bottom:14px}.aloha-carrier-compatibility-sortable-header.carrier{min-width:97px}.aloha-carrier-compatibility-sortable-header.compatibility{min-width:156px}.aloha-carrier-compatibility-sortable-header div{float:left}.aloha-carrier-compatibility-sortable-header i.a-icon{margin-left:10px;margin-top:4px}#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes th:nth-child(2n),.aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes td:nth-child(2n){background-color:transparent}.aloha-carrier-compatibility-column-gray{background-color:#f6f6f6}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text,.aloha-carrier-compatibility-modal-table-row .carrier-name,.aloha-carrier-compatibility-modal-table-row .carrier-rating-summary{min-height:27px;display:inline-block;cursor:default}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text:first-line,.aloha-carrier-compatibility-modal-table-row .carrier-name:first-line,.aloha-carrier-comp ...
#   '9742356831': '',
#   '9980454849': '',
#   'B00004S1C5': '',
#   'B00004W4VD': '',
#   'B00004Y5PN': '',
#   'B00004Z4NN': '',
#   'B000052X2S': '3.13',
#   'B000052Y74': '',
#   'B00005344V': '28.68',
#   'B000053408': '',
#   'B00005AS53': '',
#   'B00005BPQ9': '',
#   'B00005C1YG': '42.50',
#   'B00005C2ZW': '',
#   'B00005C1ZL': '34.71',
#   'B00005IX97': '64.88',
#   'B00005MOY3': '',
#   'B00005OTYO': '',
#   'B00006429V': '58.99',
#   'B000068XME': '',
#   'B000068XMG': '',
#   'B0000691JF': '',
#   'B00006B5UX': '',
#   'B00006BN4U': '40.85',
#   'B00006FMKH': '',
#   'B00006FMLY': '10.41',
#   'B00006FWVX': '6.30',
#   'B00006G930': '',
#   'B00006IDJU': '5.54',
#   'B00006IDJY': '5.18',
#   'B00006IDKF': 'a-box-inner{background-color:#fff}#alohaBuyBoxWidget .selected{background-color:#fffbf3;border-color:#e77600;box-shadow:0 0 3px rgba(228,121,17,.5)}#alohaBuyBoxWidget .contract-not-available{color:gray}#aloha-cart-popover .aloha-cart{height:auto;overflow:hidden}#aloha-cart-popover #aloha-cartInfo{float:left}#aloha-cart-popover #aloha-cart-details{float:right;margin-top:1em}#aloha-cart-popover .deviceContainer{width:160px;float:left;padding-right:10px;border-right:1px solid #ddd}#aloha-cart-popover li:last-child{border-right:0}#aloha-cart-popover .aloha-device-title{height:3em;overflow:hidden}#aloha-cart-popover .aloha-thumbnail-container{height:100px;margin-bottom:1em;text-align:center}#aloha-cart-popover .aloha-price-container{text-align:center}#aloha-cart-popover .aloha-thumbnail-container img{height:inherit}#aloha-cart-popover .aloha-cart{border-top:1px solid #ddd;border-bottom:1px solid #ddd}#aloha-cart-popover #aloha-cart-info{margin-right:0}#alohaBuyBoxWidget .without-contract-subheading{margin-right:0}#aloha-bb-help-nodes .aloha-bb-contract-term-heading{color:gray;font-family:arial;margin-top:.5em;text-align:center;height:.7em;border-bottom:1px solid gray;margin-bottom:1.6em}#aloha-bb-help-nodes .aloha-bb-contract-term-heading span{background-color:#fff;padding:0 10px 0 10px}#alohaAvailabilityUS_feature_div .availability a{text-decoration:none}#alohaPricingWidget a{text-decoration:none}#alohaAvailabilityUS_feature_div .availability{margin-top:-4px;margin-bottom:0}#alohaBuyBoxWidget .select-transaction-alert .a-icon-alert{top:18px;left:3px}#alohaBuyBoxWidget .select-transaction-alert .a-alert-container{padding-left:39px;width:290px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .contract-term-heading a{text-decoration:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .annual-contract-box .a-icon-popover{display:none}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .contract-container .annual-contract-box{cursor:pointer;cursor:hand}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget .aloha-buybox-price{font-size:15px}#alohaBuyBoxUS_feature_div #alohaBuyBoxWidget #linkOffSection a{text-decoration:none}#alohaBuyBoxUS_feature_div .lockedUsedBuyboxContainer{padding-left:3.5%}#alohaBuyBoxUS_feature_div .alohaBuyboxUtilsNoWrap{white-space:nowrap}.hidden{display:none}.simo-no-padding{padding:0}.carrier-reviews-cell{padding-left:10px}.carrier-reviews-bordered-cell{border:1px dotted #ccc}.carrier-reviews-selected-cell{background-color:#ffd}#aloha-carrier-compatibility-modal-table-description{margin-top:10px;margin-bottom:14px}.aloha-carrier-compatibility-sortable-header.carrier{min-width:97px}.aloha-carrier-compatibility-sortable-header.compatibility{min-width:156px}.aloha-carrier-compatibility-sortable-header div{float:left}.aloha-carrier-compatibility-sortable-header i.a-icon{margin-left:10px;margin-top:4px}#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-overview-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes td:nth-child(2n),#aloha-carrier-compatibility-modal-table.a-bordered.a-vertical-stripes th:nth-child(2n){background-color:initial}#aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes th:nth-child(2n),.aloha-carrier-compatibility-table.a-bordered.a-vertical-stripes td:nth-child(2n){background-color:transparent}.aloha-carrier-compatibility-column-gray{background-color:#f6f6f6}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text,.aloha-carrier-compatibility-modal-table-row .carrier-name,.aloha-carrier-compatibility-modal-table-row .carrier-rating-summary{min-height:27px;display:inline-block;cursor:default}.aloha-carrier-compatibility-modal-table-row .aloha-carrier-compatibility-tech-text:first-line,.aloha-carrier-compatibility-modal-table-row .carrier-name:first-line,.aloha-carrier-comp ...
#   'B00006IDK5': '',
#   'B00006IDK9': '30.00',
#   'B00006IDJZ': '6.99',
#   'B00006IZZZ': '',
#   'B00006RHLY': '39.99',
#   'B000089D9T': '',
#   'B00008CQRK': '14.95',
#   'B00008RCML': '',
#   'B00008RCMI': '45.00',
#   'B00008RCN8': '13.08',
#   'B000096O8Y': '',
#   'B000096P23': '',
#   'B00009WDTB': '',
#   'B00009WKUO': '17.99',
#   'B0000A0BS3': '59.17',
#   'B0000A0BS5': '',
#   'B0000A0MCW': '',
#   'B0000A1OEK': '2.99',
#   'B0000A1OEF': '5.55',
#   'B0000A9XZO': '',
#   'B0000AA8UL': '17.00',
#   'B0000AE62D': '5.64',
#   'B0000AE62K': '',
#   'B0000AE5ZF': '4.36',
#   'B0000CA4TK': '15.00',
#   'B0000CAV3L': '18.95',
#   'B0000CAV3W': '',
#   'B0000CAV37': '',
#   'B0000CAV3Y': '',
#   'B0000CAV3A': '',
#   'B0000CAV47': '',
#   'B0000CBJ49': '10.95',
#   'B0000CCZYT': '15.27',
#   'B0000CD03D': '9.38',
#   'B0000CD02P': '',
#   'B0000CD07U': '',
#   'B0000CD02T': '8.57',
#   'B0000CD07A': '',
#   'B0000CD9PL': '',
#   'B0000CDBPT': '29.99',
#   'B0000CDBQA': '',
#   'B0000CDBRX': '14.95',
#   'B0000CDC3J': '',
#   'B0000CDBQL': '',
#   'B0000CD9TE': '',
#   'B0000CDBR2': '',
#   'B0000CDE88': '',
#   'B0000CDEQE': '',
#   'B0000CDEQN': '',
#   'B0000CDBQ9': '',
#   'B0000CDBJY': '',
#   'B0000CDEPD': '48.88',
#   'B0000CDBR7': '',
#   'B0000CE3ZE': '59.99',
#   'B0000CE452': '',
#   'B0000CE3X8': '11.45',
#   'B0000CEO8F': '24.27',
#   'B0000CEO7A': '',
#   'B0000CEQUM': '',
#   'B0000CEQUJ': '',
#   'B0000CEQD5': '12.41',
#   'B0000CER5F': '',
#   'B0000CERDX': '',
#   'B0000CERE4': '',
#   'B0000CER6Z': '',
#   'B0000CERGA': '11.94',
#   'B0000CER6R': '',
#   'B0000CEQAA': '8.77',
#   'B0000CEQZS': '',
#   'B0000CERVY': '15.99',
#   'B0000CEU85': '17.90',
#   'B0000CEUC2': '',
#   'B0000CERYL': '',
#   'B0000CEQA4': '',
#   'B0000CERTG': '',
#   'B0000CEUF4': '',
#   'B0000CEU6P': '',
#   'B0000CEUFI': '',
#   'B0000CEUJO': '17.50',
#   'B0000CEUGR': '16.90',
#   'B0000CEUAB': '14.90',
#   'B0000CEUCN': '14.90',
#   'B0000CEUF9': '19.95',
#   'B0000CEUSQ': '14.99',
#   'B0000CEUXV': '11.90',
#   'B0000CERJ5': '12.99',
#   'B0000CEUF8': '19.95',
#   'B0000CEUBO': '',
#   'B0000CERIH': '',
#   'B0000CEUDZ': '13.90',
#   'B0000CEZ88': '',
#   'B0000CFH7B': '3.00',
#   'B0000CFH6P': '',
#   'B0000CFKNO': '11.95',
#   'B0000CFMQS': '13.87',
#   'B0000CFMU3': '14.99',
#   'B0000CFMU7': '9.47',
#   'B0000CFMT7': '5.78',
#   'B0000CFN6G': '',
#   'B0000CFN7X': '6.57',
#   'B0000CFN7O': '4.85',
#   'B0000CFMXD': '',
#   'B0000CFMXV': '11.87',
#   'B0000CFPI2': '9.30',
#   'B0000CFXYD': '',
#   'B0000CG4I0': '26.95',
#   'B0000CFXYG': '',
#   'B0000CG6XK': '',
#   'B0000CG41W': '23.95',
#   'B0000CGE3G': '',
#   'B0000CGFFI': '14.99',
#   'B0000CGFEK': '12.99',
#   'B0000CGE1S': '19.99',
#   'B0000CGFCD': '',
#   'B0000CGFTA': '',
#   'B0000CGFGS': '14.50',
#   'B0000CGFSC': '',
#   'B0000CGFG1': '14.99',
#   'B0000CGN6F': '44.95',
#   'B0000CGMSL': '',
#   'B0000CGFAR': '14.20',
#   'B0000CH39R': '99.95',
#   'B0000CH4GQ': '47.95',
#   'B0000CH4G9': '16.88',
#   'B0000CH3EB': '',
#   'B0000CH4FV': '25.95',
#   'B0000CH4GF': '',
#   'B0000CH4GM': '9.22',
#   'B0000CH4GU': '',
#   'B0000CH4FT': '11.99',
#   'B0000CH4GY': '8.99',
#   'B0000CH4FA': '',
#   'B0000CH4FX': '23.89',
#   'B0000CH4G5': '8.99',
#   'B0000CNTZI': '5.98',
#   'B0000CNTZK': '',
#   'B0000CNU0A': '',
#   'B0000CNU0P': '6.99',
#   'B0000CNU0U': '',
#   'B0000CNU07': '',
#   'B0000CNU0K': '7.99',
#   'B0000CNTZJ': '',
#   'B0000CNU01': '',
#   'B0000CNTSH': '',
#   'B0000CNU0Z': '',
#   'B0000CNTZE': '',
#   'B0000CNU19': '10.00',
#   'B0000CNU0X': '',
#   'B0000CNU28': '4.40',
#   'B0000CNU0C': '5.91',
#   'B0000CNTZL': '',
#   'B0000CNU1A': '14.99',
#   'B0000CNU1B': '14.24',
#   'B0000CNU0N': '',
#   'B0000CNU0W': '',
#   'B0000CNU03': '5.60',
#   'B0000CNU3R': '15.99',
#   'B0000CNU0B': '',
#   'B0000CNU3M': '',
#   'B0000CNU56': '10.06',
#   'B0000CNU2K': '20.50',
#   'B0000CNU1Z': '5.44',
#   'B0000CNU48': '9.95',
#   'B0000CNU1Q': '',
#   'B0000CNU3J': '10.99',
#   'B0000CNU1S': '',
#   'B0000CNU5A': '7.96',
#   'B0000CNU4P': '',
#   'B0000CNU4H': '',
#   'B0000CNU2H': '1.85',
#   'B0000CNU5B': '9.99',
#   'B0000CNU0Y': '',
#   'B0000CNU57': '14.70',
#   'B0000CNU3P': '',
#   'B0000CNU0I': '6.99',
#   'B0000CNU6Q': '',
#   'B0000CNU5G': '',
#   'B0000CNU58': '13.79',
#   'B0000CNU5Q': '7.99',
#   'B0000CNU3F': '9.99',
#   'B0000CNU61': '',
#   'B0000CNU72': '12.21',
#   'B0000CNU2Q': '',
#   'B0000CNU4J': '',
#   'B0000CNU5W': '13.84',
#   'B0000CNU2J': '',
#   'B0000CNU2F': '8.66',
#   'B0000CNU69': '65.61',
#   'B0000CNU0R': '',
#   'B0000CNU77': '',
#   'B0000CNU1X': '',
#   'B0000CNU4K': '8.99',
#   'B0000CNU75': '18.98',
#   'B0000CNU5N': '20.61',
#   'B0000CNU12': '',
#   'B0000CNU2B': '',
#   'B0000CNU1J': '9.24',
#   'B0000CNU5H': '',
#   'B0000CNU6H': '11.49',
#   'B0000CNU2N': '',
#   'B0000CNU74': '',
#   'B0000CNU5D': '12.97',
#   'B0000CNU55': '13.61',
#   'B0000CNU6V': '9.42',
#   'B0000CNU6X': '14.99',
#   'B0000CNU1F': '',
#   'B0000CNU78': '22.01',
#   'B0000CNU5R': '',
#   'B0000CNU64': '',
#   'B0000CNU50': '10.79',
#   'B0000CNU6Z': '12.99',
#   'B0000CNU15': '8.59',
#   'B0000CNU2R': '',
#   'B0000CNU7C': '',
#   'B0000CNU6W': '',
#   'B0000CNU5T': '',
#   'B0000CNU1O': '',
#   'B0000CNU6S': '14.84',
#   'B0000CNU6U': '10.88',
#   'B0000CNU5U': '18.98',
#   'B0000CNU66': '8.32',
#   'B0000CNU45': '10.58',
#   'B0000CNU6P': '31.71',
#   'B0000CNU59': '10.65',
#   'B0000CNU0L': '6.99',
#   'B0000D15HO': '6.34',
#   'B0000D15X9': '9.99',
#   'B0000D15YU': '',
#   'B0000D12X0': '',
#   'B0000D1666': '',
#   'B0000D15YQ': '28.10',
#   'B0000D1673': '',
#   'B0000D1638': '19.78',
#   'B0000D16CT': '',
#   'B0000D16QZ': '',
#   'B0000D15LK': '',
#   'B0000D16M2': '',
#   'B0000D1699': '',
#   'B0000D15S0': '',
#   'B0000D16L3': '12.95',
#   'B0000D16IP': '16.23',
#   'B0000D176P': '',
#   'B0000D15MQ': '',
#   'B0000D1686': '',
#   'B0000D15WD': '',
#   'B0000D1692': '',
#   'B0000D16GI': '',
#   'B0000D17A0': '10.96',
#   'B0000D179H': '',
#   'B0000D17CJ': '',
#   'B0000D17FC': '',
#   'B0000D17D4': '',
#   'B0000D17MK': '',
#   'B0000D1685': '',
#   'B0000D17HA': '7.99',
#   'B0000D17DJ': '',
#   'B0000D17NR': '',
#   'B0000D16CV': '',
#   'B0000D17AG': '4.59',
#   'B0000D179S': '5.96',
#   'B0000D15YX': '',
#   'B0000D17RQ': '12.98',
#   'B0000D17W6': '',
#   'B0000D17HO': '',
#   'B0000D17OX': '',
#   'B0000D16YK': '',
#   'B0000D16CN': '',
#   'B0000D17S0': '9.43',
#   'B0000D17HR': '13.34',
#   'B0000D17RB': '7.79',
#   'B0000D19AB': '',
#   'B0000D179V': '',
#   'B0000D17UV': '',
#   'B0000D198T': '12.49',
#   'B0000D17UF': '22.76',
#   'B0000D176S': '',
#   'B0000D17UD': '43.88',
#   'B0000D17YL': '',
#   'B0000D16CM': '',
#   'B0000D17J6': '',
#   'B0000D17L9': '14.66',
#   'B0000D17HK': '3.76',
#   'B0000D17HQ': '',
#   'B0000D17CF': '1.43',
#   'B0000D174Q': '',
#   'B0000D177E': '',
#   'B0000D17R9': '',
#   'B0000D17NY': '',
#   'B0000D17ST': '',
#   'B0000D166U': '',
#   'B0000D17OZ': '14.99',
#   'B0000D16IO': '',
#   'B0000D17X3': '',
#   'B0000D18YP': '8.40',
#   'B0000D17YU': '6.48',
#   'B0000D17M5': '14.95',
#   'B0000D16V0': '2.99',
#   'B0000D198Q': '',
#   'B0000D17P0': '',
#   'B0000D17NM': '10.95',
#   'B0000D17TA': '9.99',
#   'B0000D167Z': '',
#   'B0000D17YI': '',
#   'B0000D17G0': '',
#   'B0000D878H': '',
#   'B0000D879R': '',
#   'B0000D88Z4': '',
#   'B0000D88RV': '',
#   'B0000D8AE6': '',
#   'B0000D89QY': '',
#   'B0000D8CO0': '',
#   'B0000D88B6': '',
#   'B0000D89EJ': '',
#   'B0000D89R7': '',
#   'B0000D89R5': '',
#   'B0000D8DI0': '8.32',
#   'B0000D88C1': '',
#   'B0000D8GHR': '',
#   'B0000D8GL3': '',
#   'B0000D8GI2': '',
#   'B0000D8GHU': '',
#   'B0000D8KJI': '',
#   'B0000D8KJC': '8.03',
#   'B0000D8KJ8': '',
#   'B0000D8Q90': '20.99',
#   'B0000D91KB': '',
#   'B0000D94MA': '',
#   'B0000D94PZ': '',
#   'B0000D94PP': '3.59',
#   'B0000D916Y': '',
#   'B0000D94U0': '',
#   'B0000D94PL': '3.59',
#   'B0000D94SB': '',
#   'B0000D94UI': '',
#   'B0000D94V9': '',
#   'B0000D952M': '',
#   'B0000D9517': '',
#   'B0000D953W': '',
#   'B0000D954D': '4.73',
#   'B0000D956L': '',
#   'B0000D95A3': '',
#   'B0000D94RL': '',
#   'B0000D94PA': '3.59',
#   'B0000D9589': '',
#   'B0000D94RZ': '',
#   'B0000D94N3': '',
#   'B0000D952D': '',
#   'B0000D94M3': '',
#   'B0000D94OR': '',
#   'B0000D9541': '',
#   'B0000D94PU': '',
#   'B0000D9MSD': '9.99',
#   'B0000D94TV': '',
#   'B0000D9MUE': '8.99',
#   'B0000D9MSH': '15.99',
#   'B0000D94ZQ': '',
#   'B0000D9MV7': '17.99',
#   'B0000D9MWT': '',
#   'B0000D94R9': '',
#   'B0000D9MTS': '26.99',
#   'B0000D9MVO': '12.99',
#   'B0000D9MYD': '',
#   'B0000D9169': '38.95',
#   'B0000D9MXU': '15.99',
#   'B0000D9MYH': '',
#   'B0000D956H': '',
#   'B0000D94WF': '',
#   'B0000D9MU1': '42.97',
#   'B0000D9MU2': '15.99',
#   'B0000D9MY3': '35.99',
#   'B0000D9N0F': '11.99',
#   'B0000D9MYG': '',
#   'B0000D9MYV': '24.98',
#   'B0000D9MYJ': '14.99',
#   'B0000D9N12': '16.99',
#   'B0000D9MUM': '',
#   'B0000D9MZM': '32.99',
#   'B0000D9MYC': '28.97',
#   'B0000D9MRQ': '',
#   'B0000D9MVT': '15.99',
#   'B0000D9N0Q': '27.27',
#   'B0000D9MR9': '59.99',
#   'B0000D9N33': '',
#   'B0000D9MYM': '27.97',
#   'B0000D9N1H': '34.99',
#   'B0000D9N3O': '19.99',
#   'B0000D9N31': '16.99',
#   'B0000D9MUX': '35.99',
#   'B0000D9MTI': '19.99',
#   'B0000D9MY0': '29.99',
#   'B0000D9N3T': '2.99',
#   'B0000D9MYF': '',
#   'B0000D9MYZ': '9.99',
#   'B0000D9N50': '',
#   'B0000D9N5Q': '',
#   'B0000D9MQV': '',
#   'B0000D9N5P': '7.99',
#   'B0000D9N74': '',
#   'B0000D9N72': '5.99',
#   'B0000D9N38': '17.97',
#   'B0000D9N7C': '8.00',
#   'B0000D9MXL': '16.99',
#   'B0000D9N6N': '10.99',
#   'B0000D9N9A': '17.99',
#   'B0000D9N0I': '9.99',
#   'B0000D9N22': '6.79',
#   'B0000D9N7R': '29.99',
#   'B0000D9MV3': '9.99',
#   'B0000D9N39': '22.02',
#   'B0000D9N17': '26.99',
#   'B0000D9NC9': '6.99',
#   'B0000D9MZN': '27.45',
#   'B0000D9NB5': '8.99',
#   'B0000D9NCI': '',
#   'B0000D9N7T': '13.86',
#   'B0000D9N18': '52.99',
#   'B0000D95AO': '',
#   'B0000D9N9X': '7.99',
#   'B0000D9MT2': '10.49',
#   'B0000D9N8C': '9.99',
#   'B0000D9N4P': '',
#   'B0000D9N8Z': '24.99',
#   'B0000D9N2Q': '7.99',
#   'B0000D9NDF': '12.99',
#   'B0000D9MSP': '298.99',
#   'B0000D9N3M': '',
#   'B0000D9MX7': '20.97',
#   'B0000D9N59': '',
#   'B0000D9MT1': '12.20',
#   'B0000D9N2C': '',
#   'B0000D9N6T': '19.49',
#   'B0000D9N7H': '',
#   'B0000D9NBM': '',
#   'B0000D9N4M': '21.99',
#   'B0000D9N44': '12.99',
#   'B0000D9N5T': '',
#   'B0000D9NCK': '12.49',
#   'B0000D9N8O': '36.99',
#   'B0000D9N64': '6.99',
#   'B0000D9NAN': '7.99',
#   'B0000D9N0J': '18.85',
#   'B0000D9N8U': '',
#   'B0000D9N63': '37.99',
#   'B0000D9N9I': '49.99',
#   'B0000D9MYO': '11.99',
#   'B0000D9N3E': '11.99',
#   'B0000D9N1E': '3.99',
#   'B0000D9N62': '10.99',
#   'B0000D9NDC': '14.99',
#   'B0000D9N68': '17.50',
#   'B0000D9N7E': '7.99',
#   'B0000DA0XE': '',
#   'B0000DA0XJ': '21.50',
#   'B0000DANYX': '27.45',
#   'B0000D9NAR': '',
#   'B0000DBN1H': '',
#   'B0000DBN1G': '',
#   'B0000DBN1O': '',
#   'B0000DBN2F': '5.95',
#   'B0000DBN2K': '15.02',
#   'B0000DBN1M': '',
#   'B0000DBN1L': '12.02',
#   'B0000DBKG1': '',
#   'B0000DBN2J': '',
#   'B0000DBN2E': '',
#   'B0000DC2T3': '107.99',
#   'B0000DC2T7': '',
#   'B0000DC2UH': '35.62',
#   'B0000DC2TH': '',
#   'B0000DC2V5': '21.90',
#   'B0000DC2UP': '',
#   'B0000DC2TL': '',
#   'B0000DC32J': '',
#   'B0000DC2TU': '',
#   'B0000DC2VT': '23.95',
#   'B0000DC2U9': '',
#   'B0000DC2U7': '8.97',
#   'B0000DC2U4': '39.99',
#   'B0000DC2VW': '8.55',
#   'B0000DC32S': '12.74',
#   'B0000DC2VN': '11.13',
#   'B0000DC324': '13.66',
#   'B0000DC32H': '12.74',
#   'B0000DC2TD': '34.72',
#   'B0000DC2UR': '19.99',
#   'B0000DC61M': '',
#   'B0000DC5UH': '',
#   'B0000DC2UV': '25.87',
#   'B0000DC4OR': '',
#   'B0000DC5UM': '5.79',
#   'B0000DC4OV': '7.97',
#   'B0000DC4ZR': '',
#   'B0000DCK36': '',
#   'B0000DCWWB': '',
#   'B0000DCWYJ': '',
#   'B0000DCWW5': '',
#   'B0000DCWT7': '',
#   'B0000DCX9C': '',
#   'B0000DCX95': '',
#   'B0000DCXDH': '',
#   'B0000DCXCM': '',
#   'B0000DCX96': '',
#   'B0000DCKGI': '',
#   'B0000DCWZA': '',
#   'B0000DCXDL': '',
#   'B0000DCXBQ': '',
#   'B0000DCXC8': '',
#   'B0000DCXES': '',
#   'B0000DCKCN': '89.99',
#   'B0000DCXF3': '',
#   'B0000DCXHH': '',
#   'B0000DCXBH': '',
#   'B0000DCXAE': '',
#   'B0000DCYLK': '',
#   'B0000DCXFY': '',
#   'B0000DCXEU': '',
#   'B0000DCYML': '',
#   'B0000DCYMX': '32.95',
#   'B0000DCYM6': '',
#   'B0000DCXDQ': '',
#   'B0000DCYLF': '',
#   'B0000DCYM0': '',
#   'B0000DCYMK': '',
#   'B0000DCYN9': '',
#   'B0000DCXG2': '',
#   'B0000DCXH0': '',
#   'B0000DCXGJ': '',
#   'B0000DCYLG': '',
#   'B0000DCWWI': '',
#   'B0000DCXDR': '',
#   'B0000DD8PB': '',
#   'B0000DD8XD': '',
#   'B0000DD8YP': '',
#   'B0000DD8YC': '',
#   'B0000DD8RB': '7.99',
#   'B0000DD8ZK': '',
#   'B0000DD8X7': '',
#   'B0000DDSCE': '',
#   'B0000DDSDX': '',
#   'B0000DDSC9': '11.15',
#   'B0000DDSDQ': '18.16',
#   'B0000DDSDT': '',
#   'B0000DF44M': '',
#   'B0000DF3VT': '',
#   'B0000DF3WM': '13.58',
#   'B0000DF3WB': '39.95',
#   'B0000DF3IZ': '',
#   'B0000DFZNX': '',
#   'B0000DF3M8': '',
#   'B0000DF43M': '',
#   'B0000DF3FC': '',
#   'B0000DG4B1': '',
#   'B0000DG4MK': '11.98',
#   'B0000DG4NL': '',
#   'B0000DG4NM': '14.99',
#   'B0000DG4NE': '14.95',
#   'B0000DG53R': '',
#   'B0000DG4M6': '6.99',
#   'B0000DG54Z': '',
#   'B0000DG55X': '',
#   'B0000DG55O': '',
#   'B0000DG4MU': '14.49',
#   'B0000DG56A': '',
#   'B0000DG553': '',
#   'B0000DG573': '',
#   'B0000DG55M': '',
#   'B0000DG55U': '',
#   'B0000DG54W': '',
#   'B0000DG57D': '16.95',
#   'B0000DG54P': '',
#   'B0000DG4MX': '',
#   'B0000DG57K': '',
#   'B0000DG5AA': '6.07',
#   'B0000DG4M3': '6.89',
#   'B0000DG5AP': '',
#   'B0000DG55R': '10.98',
#   'B0000DG5BQ': '',
#   'B0000DG55K': '12.95',
#   'B0000DG5AO': '14.75',
#   'B0000DG5BN': '13.95',
#   'B0000DG58W': '14.95',
#   'B0000DG5CE': '13.79',
#   'B0000DG4ML': '18.18',
#   'B0000DG567': '17.49',
#   'B0000DG59Q': '110.95',
#   'B0000DG5AN': '9.49',
#   'B0000DG5E7': '13.38',
#   'B0000DG5C7': '9.99',
#   'B0000DG56P': '9.50',
#   'B0000DG588': '',
#   'B0000DG5BP': '',
#   'B0000DG55L': '11.99',
#   'B0000DG5ED': '9.99',
#   'B0000DG5B6': '',
#   'B0000DG5BV': '18.27',
#   'B0000DG57P': '',
#   'B0000DG5CF': '8.11',
#   'B0000DG5EE': '9.75',
#   'B0000DG5AF': '',
#   'B0000DG55I': '',
#   'B0000DG6WL': '35.90',
#   'B0000DG6Y0': '30.35',
#   'B0000DG58T': '7.74',
#   'B0000DG4MS': '',
#   'B0000DG5A8': '13.22',
#   'B0000DG5AB': '14.99',
#   'B0000DG71N': '24.67',
#   'B0000DG6ZW': '',
#   'B0000DG71T': '73.67',
#   'B0000DG5CD': '10.01',
#   'B0000DG87B': '',
#   'B0000DG737': '44.95',
#   'B0000DG8AQ': '',
#   'B0000DG871': '',
#   'B0000DG57Q': '5.99',
#   'B0000DG72O': '40.00',
#   'B0000DG6WN': '',
#   'B0000DG8AR': '29.99',
#   'B0000DGD7O': '',
#   'B0000DG86X': '',
#   'B0000DGD7Q': '',
#   'B0000DGDPF': '',
#   'B0000DGF5P': '44.95',
#   'B0000DGEOW': '',
#   'B0000DGFEE': '',
#   'B0000DGF5U': '',
#   'B0000DGG22': '',
#   'B0000DGFCO': '',
#   'B0000DGG51': '',
#   'B0000DGG4Y': '',
#   'B0000DGENZ': '',
#   'B0000DGG89': '',
#   'B0000DG5EC': '13.54',
#   'B0000DGG8B': '',
#   'B0000DGDOI': '',
#   'B0000DGFCS': '',
#   'B0000DGFCL': '69.99',
#   'B0000DGG24': '',
#   'B0000DGFA5': '',
#   'B0000DGF9V': '',
#   'B0000DGGMI': '143.49',
#   'B0000DGFCW': '',
#   'B0000DI0OE': '4.47',
#   'B0000DHZCG': '',
#   'B0000DI085': '4.46',
#   'B0000DHZCO': '',
#   'B0000DHXGL': '62.98',
#   'B0000DHXLY': '',
#   'B0000DHZOA': '',
#   'B0000DHZZB': '21.49',
#   'B0000DI0EX': '',
#   'B0000DHXGI': '',
#   'B0000DI145': '5.43',
#   'B0000DI1IG': '',
#   'B0000DHXAK': '',
#   'B0000DHZT8': '8.81',
#   'B0000DI0KA': '13.70',
#   'B0000DHZY1': '32.57',
#   'B0000DI1E8': '9.20',
#   'B0000DI1EC': '8.19',
#   'B0000DI0GU': '',
#   'B0000DHZ3W': '',
#   'B0000DIC1N': '',
#   'B0000DID5S': '8.39',
#   'B0000DID5R': '',
#   'B0000DID5W': '9.95',
#   'B0000DID5X': '12.95',
#   'B0000DID62': '7.97',
#   'B0000DID6A': '',
#   'B0000DID7E': '18.82',
#   'B0000DID64': '',
#   'B0000DID63': '8.41',
#   'B0000DID7I': '',
#   'B0000DID7D': '',
#   'B0000DID77': '34.99',
#   'B0000DID78': '',
#   'B0000DID7A': '',
#   'B0000DID6E': '14.15',
#   'B0000DIFMY': '',
#   'B0000DID6T': '',
#   'B0000DID7M': '13.76',
#   'B0000DIEJ1': '',
#   'B0000DIFWS': '',
#   'B0000DIPJC': '9.38',
#   'B0000DIPJA': '9.99',
#   'B0000DISUY': '11.90',
#   'B0000DIRZS': '12.00',
#   'B0000DISV6': '28.50',
#   'B0000DISV9': '12.50',
#   'B0000DIRZR': '11.00',
#   'B0000DIVU9': '28.99',
#   'B0000DISV7': '12.40',
#   'B0000DISV4': '14.50',
#   'B0000DIPMM': '22.08',
#   'B0000DIVU7': '',
#   'B0000DIWKP': '',
#   'B0000DIVUB': '29.00',
#   'B0000DIWKH': '',
#   'B0000DIWR3': '40.00',
#   'B0000DIWKM': '',
#   'B0000DIWWD': '',
#   'B0000DIWWE': '18.99',
#   'B0000DIWIQ': '',
#   'B0000DIX2Y': '',
#   'B0000DIX2U': '14.50',
#   'B0000DIQG9': '',
#   'B0000DIX32': '',
#   'B0000DIXKS': '',
#   'B0000DIXKU': '35.20',
#   'B0000DIYI7': '',
#   'B0000DISV8': '14.50',
#   'B0000DIYIJ': '',
#   'B0000DIYK1': '38.50',
#   'B0000DIYK6': '26.75',
#   'B0000DIYK3': '15.00',
#   'B0000DIYK0': '',
#   'B0000DIYKE': '',
#   'B0000DIYIF': '',
#   'B0000DIYW7': '15.50',
#   'B0000DIYW1': '15.50',
#   'B0000DIYVM': '20.24',
#   'B0000DIYUP': '14.50',
#   'B0000DIYUV': '13.49',
#   'B0000DIYWF': '15.50',
#   'B0000DIYII': '28.14',
#   'B0000DIYWB': '15.50',
#   'B0000DIYIG': '10.65',
#   'B0000DIYWO': '18.99',
#   'B0000DIYK7': '28.00',
#   'B0000DIYUT': '15.50',
#   'B0000DIYU6': '14.50',
#   'B0000DIYIL': '11.98',
#   'B0000DIYWZ': '',
#   'B0000DIYVQ': '13.99',
#   'B0000DJ7TY': '',
#   'B0000DJ7TL': '',
#   'B0000DIYKF': '12.48',
#   'B0000DJ7SX': '31.99',
#   'B0000DJ7W5': '',
#   'B0000DJ7Z6': '',
#   'B0000DIYVO': '15.50',
#   'B0000DJ7XE': '24.99',
#   'B0000DJ88P': '67.99',
#   'B0000DJ81T': '84.99',
#   'B0000DIYUX': '15.50',
#   'B0000DJ7XG': '25.99',
#   'B0000DJ7SR': '',
#   'B0000DJ6NI': '23.20',
#   'B0000DJ7VQ': '',
#   'B0000DJ7SD': '54.99',
#   'B0000DJ7SA': '',
#   'B0000DJ7YW': '97.99',
#   'B0000DJ7YT': '58.99',
#   'B0000DJ89S': '45.99',
#   'B0000DJ89O': '74.99',
#   'B0000DJ6NG': '11.86',
#   'B0000DJ7T0': '44.99',
#   'B0000DJ85D': '',
#   'B0000DJ81R': '99.00',
#   'B0000DJ89Q': '24.99',
#   'B0000DJDHJ': '',
#   'B0000DJDJX': '',
#   'B0000DJDL4': '52.98',
#   'B0000DJDHN': '',
#   'B0000DJFG8': '',
#   'B0000DJETH': '',
#   'B0000DJESD': '',
#   'B0000DJFDY': '',
#   'B0000DJF59': '',
#   'B0000DJT4I': '13.81',
#   'B0000DJT38': '10.96',
#   'B0000DJT1J': '35.95',
#   'B0000DK2WM': '',
#   'B0000DK39I': '',
#   'B0000DK4E0': '4.25',
#   'B0000DK4G4': '4.25',
#   'B0000DK463': '',
#   'B0000DK3Z1': '',
#   'B0000DK4J0': '4.75',
#   'B0000DK527': '',
#   'B0000DK5KE': '4.75',
#   'B0000DK59J': '',
#   'B0000DK59A': '4.75',
#   'B0000DK56B': '4.75',
#   'B0000DK36Z': '',
#   'B0000DK5JJ': '4.75',
#   'B0000DK5SQ': '4.75',
#   'B0000DK5RS': '4.75',
#   'B0000DK4WM': '4.75',
#   'B0000DK5DR': '4.75',
#   'B0000DK5WY': '4.75',
#   'B0000DK4SL': '',
#   'B0000DK671': '4.75',
#   'B0000DK43R': '4.75',
#   'B0000DK92B': '6.95',
#   'B0000DK95R': '6.95',
#   'B0000DK6UV': '4.75',
#   'B0000DK6DL': '4.75',
#   'B0000DK6KB': '',
#   'B0000DK9WZ': '6.95',
#   'B0000DK9YW': '6.95',
#   'B0000DK6XP': '4.75',
#   'B0000DKBS4': '25.00',
#   'B0000DK917': '6.95',
#   'B0000DKA6J': '21.00',
#   'B0000DK6IV': '',
#   'B0000DK97W': '6.95',
#   'B0000DKBH3': '16.00',
#   'B0000DK9NS': '6.95',
#   'B0000DK9W4': '6.95',
#   'B0000DK6PO': '4.75',
#   'B0000DKB71': '20.00',
#   'B0000DK6K5': '',
#   'B0000DK6P5': '4.75',
#   'B0000DK6UD': '4.75',
#   'B0000DKQ59': '25.98',
#   'B0000DK9VS': '6.95',
#   'B0000DK9QU': '6.95',
#   'B0000DYGAF': '',
#   'B0000DYNFH': '13.80',
#   'B0000DYNFC': '11.90',
#   'B0000DYNFF': '14.50',
#   'B0000DYNFN': '10.90',
#   'B0000DYZC1': '107.85',
#   'B0000DZ0Q6': '275.70',
#   'B0000DYZCA': '381.40',
#   'B0000DYVMJ': '',
#   'B0000DZ0Q3': '129.95',
#   'B0000DYZBN': '',
#   'B0000DZ0PP': '83.84',
#   'B0000DZ0Q4': '174.49',
#   'B0000DZBO3': '',
#   'B0000DZC7E': '',
#   'B0000DZEV2': '38.06',
#   'B0000DZCFS': '',
#   'B0000DZLTG': '',
#   'B0000DZEYP': '',
#   'B0000DZLTY': '8.99',
#   'B0000E1VU8': '',
#   'B0000E1VRX': '',
#   'B0000E1VUG': '',
#   'B0000E224F': '',
#   'B0000E222W': '',
#   'B0000E221W': '',
#   'B0000E223C': '',
#   'B0000E2EOU': '14.84',
#   'B0000E21YI': '',
#   'B0000E227B': '',
#   'B0000E2EOV': '14.79',
#   'B0000E2EPD': '13.42',
#   'B0000E227M': '',
#   'B0000E21ZU': '',
#   'B0000E2EP0': '22.01',
#   'B0000E21XE': '',
#   'B0000E21Y2': '',
#   'B0000E2FI0': '58.70',
#   'B0000E2PX6': '8.99',
#   'B0000E2EP4': '10.88',
#   'B0000E2T6F': '4.99',
#   'B0000E2T5X': '',
#   'B0000E2T69': '',
#   'B0000E2T63': '14.48',
#   'B0000E2T62': '6.99',
#   'B0000E2T68': '13.94',
#   'B0000E2T6E': '',
#   'B0000E2T64': '',
#   'B0000E2YA0': '8.00',
#   'B0000E2Y9T': '19.59',
#   'B0000E2YA1': '',
#   'B0000E2Y9K': '18.50',
#   'B0000E2Y9O': '25.98',
#   'B0000E2Y6J': '21.50',
#   'B0000E2YFI': '11.07',
#   'B0000E2Y9X': '17.99',
#   'B0000E5IHG': '54.99',
#   'B0000E5JID': '',
#   'B0000E5JI4': '',
#   'B0000E5IGB': '29.90',
#   'B0000E5IH6': '27.37',
#   'B0000E5JIU': '',
#   'B0000E5JK7': '9.99',
#   'B0000E5JJD': '',
#   'B0000E5JM2': '',
#   'B0000E5JLJ': '',
#   'B0000E5JK8': '9.99',
#   'B0000E5JKD': '9.64',
#   'B0000E5IHL': '37.99',
#   'B0000E5JN9': '',
#   'B0000E5JKC': '5.19',
#   'B0000E5JOT': '',
#   'B0000E5JOC': '',
#   'B0000E5JPE': '13.25',
#   'B0000E5JIZ': '',
#   'B0000E5JQ5': '2.99',
#   'B0000E5JP1': '',
#   'B0000E5JRL': '',
#   'B0000E5JM4': '7.95',
#   'B0000E5JPA': '',
#   'B0000E5JL5': '5.65',
#   'B0000E5JNR': '',
#   'B0000E5JKV': '10.29',
#   'B0000E5JJ2': '10.99',
#   'B0000E5JRO': '',
#   'B0000E5JNB': '',
#   'B0000E5JX3': '',
#   'B0000E5JMD': '',
#   'B0000E5L18': '37.99',
#   'B0000E5KZR': '13.99',
#   'B0000E5L3U': '68.82',
#   'B0000E5JLT': '12.25',
#   'B0000E5JO4': '35.71',
#   'B0000E5JRZ': '5.99',
#   'B0000E5JT4': '',
#   'B0000E5JQ1': '8.06',
#   'B0000E5JRX': '11.98',
#   'B0000E5L0J': '11.99',
#   'B0000E5JRS': '7.59',
#   'B0000E5L1S': '36.86',
#   'B0000E5JU6': '',
#   'B0000E5L4E': '19.15',
#   'B0000E5JP7': '',
#   'B0000E5L3E': '49.95',
#   'B0000E5JK9': '9.06',
#   'B0000E5M9I': '',
#   'B0000E5MA3': '54.48',
#   'B0000E5JLQ': '',
#   'B0000E5JM6': '',
#   ...},
#  'item2category': {'0681727810': ['Grocery & Gourmet Food',
#    'Dairy, Cheese & Eggs',
#    'Cheese',
#    'Gouda'],
#   '0853347867': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Sugar Substitutes',
#    'Xylitol'],
#   '1888861118': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '1888861517': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '1888861614': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '1888861533': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '1888861339': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '1888861355': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '188886155X': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '1888861207': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Cake & Cupcake Toppers',
#    'Cake Toppers'],
#   '4639725043': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Tea',
#    'Black'],
#   '4639725183': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Tea',
#    'Black'],
#   '4858582000': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Tea',
#    'Tea Samplers'],
#   '5236363640': ['Grocery & Gourmet Food',
#    'Canned, Jarred & Packaged Foods',
#    'Packaged Meals & Side Dishes',
#    'Indian Dishes'],
#   '541255556X': ['Grocery & Gourmet Food',
#    'Canned, Jarred & Packaged Foods',
#    'Packaged Meals & Side Dishes',
#    'Indian Dishes'],
#   '5463213682': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Coffee'],
#   '5478541265': ['Grocery & Gourmet Food',
#    'Canned, Jarred & Packaged Foods',
#    'Packaged Meals & Side Dishes',
#    'Indian Dishes'],
#   '5643467860': ['Grocery & Gourmet Food',
#    'Canned, Jarred & Packaged Foods',
#    'Meat, Poultry & Seafood',
#    'Seafood',
#    'Tuna Fish'],
#   '6040343958': ['Grocery & Gourmet Food', 'Breads & Bakery', 'Cakes'],
#   '6040763906': ['Grocery & Gourmet Food', 'Frozen', 'Ice Cream & Novelties'],
#   '6163058011': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Tea',
#    'Tea Samplers'],
#   '618205610X': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Nuts & Seeds',
#    'Sesame Seeds'],
#   '6182055979': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Bottled Beverages, Water & Drink Mixes',
#    'Water'],
#   '6182056010': ['Grocery & Gourmet Food',
#    'Dried Beans, Grains & Rice',
#    'Grains & Rice'],
#   '7107272160': ['Grocery & Gourmet Food',
#    'Produce',
#    'Fresh Vegetables',
#    'Mushrooms & Truffles',
#    'Black Truffles'],
#   '7531848279': ['Grocery & Gourmet Food',
#    'Produce',
#    'Fresh Vegetables',
#    'Mushrooms & Truffles',
#    'Straw'],
#   '7656543546': ['Grocery & Gourmet Food',
#    'Dried Beans, Grains & Rice',
#    'Lentils'],
#   '7621000880': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Coffee',
#    'Single-Serve Capsules & Pods'],
#   '7656453768': ['Grocery & Gourmet Food', 'Beverages'],
#   '7656453458': ['Grocery & Gourmet Food', 'Cooking & Baking', 'Thickeners'],
#   '7621915358': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Cocoa'],
#   '7800648702': ['Grocery & Gourmet Food',
#    'Breads & Bakery',
#    'Fresh Baked Cookies'],
#   '8166679507': ['Grocery & Gourmet Food', 'Food & Beverage Gifts'],
#   '8557758987': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Cooking Oils, Vinegars & Sprays',
#    'Oils',
#    'Vegetable'],
#   '9177121805': ['Grocery & Gourmet Food',
#    'Snack Foods',
#    'Crackers',
#    'Flatbread'],
#   '9177121791': ['Grocery & Gourmet Food',
#    'Snack Foods',
#    'Crackers',
#    'Flatbread'],
#   '9178894018': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Coffee Substitutes'],
#   '9178902568': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Coffee',
#    'Roasted Coffee Beans'],
#   '9178894999': ['Grocery & Gourmet Food',
#    'Snack Foods',
#    'Crackers',
#    'Flatbread'],
#   '9178915155': ['Grocery & Gourmet Food',
#    'Snack Foods',
#    'Crackers',
#    'Flatbread'],
#   '9552900026': ['Grocery & Gourmet Food',
#    'Beverages',
#    'Coffee, Tea & Cocoa',
#    'Tea',
#    'Herbal'],
#   '9717894531': ['Grocery & Gourmet Food',
#    'Herbs, Spices & Seasonings',
#    'Single Herbs & Spices',
#    'Cinnamon'],
#   '9742356831': ['Grocery & Gourmet Food',
#    'Sauces, Gravies & Marinades',
#    'Sauces',
#    'Asian',
#    'Curry Sauce'],
#   '9980454849': ['Grocery & Gourmet Food',
#    'Frozen',
#    'Seafood',
#    'Frozen Shellfish'],
#   'B00004S1C5': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Food Coloring'],
#   'B00004W4VD': ['Grocery & Gourmet Food',
#    'Snack Foods',
#    'Jerky & Dried Meats'],
#   'B00004Y5PN': ['Grocery & Gourmet Food',
#    'Cooking & Baking',
#    'Frosting, Icing & Decorations',
#    'Sprinkles & Glitters',
#    'Sprinkles'],
#   'B00004Z4NN': ['Grocery & Gourmet Food',
#    'Candy & Chocolate',
#    'Hard Candy & Lollipops',
#    'Hard Candy'],
#   'B000052X2S': ['Grocery & Gourmet Food',
#    'Candy & Chocolate',
#    'Hard Candy & Lollipops',
#    'Hard Candy'],
#   'B000052Y74': ['Grocery & Gourmet Food',
#    'Candy & Chocolate',
#    'Chewing & Bubble Gum'],
# ...
#   'B0000D9NAN': 'Fratelli Beretta',
#   'B0000D9N0J': 'igourmet',
#   'B0000D9N8U': 'igourmet',
#   'B0000D9N63': 'igourmet',
#   'B0000D9N9I': 'Emmi',
#   'B0000D9MYO': 'Olivado',
#   'B0000D9N3E': 'Marich',
#   'B0000D9N1E': 'La Grande Ruote',
#   'B0000D9N62': 'igourmet',
#   'B0000D9NDC': 'igourmet',
#   'B0000D9N68': 'Vermont Creamery',
#   'B0000D9N7E': 'igourmet',
#   'B0000DA0XE': '',
#   'B0000DA0XJ': "David's Cookies",
#   'B0000DANYX': 'Lakewood',
#   'B0000D9NAR': 'DECCI',
#   'B0000DBN1H': 'TAZO',
#   'B0000DBN1G': 'TAZO',
#   'B0000DBN1O': 'TAZO',
#   'B0000DBN2F': 'TAZO',
#   'B0000DBN2K': 'TAZO',
#   'B0000DBN1M': 'TAZO',
#   'B0000DBN1L': 'TAZO',
#   'B0000DBKG1': '',
#   'B0000DBN2J': 'TAZO',
#   'B0000DBN2E': 'Boba Tea Direct',
#   'B0000DC2T3': 'Harney & Sons',
#   'B0000DC2T7': 'Harney & Sons',
#   'B0000DC2UH': 'Harney & Sons',
#   'B0000DC2TH': 'Harney & Sons',
#   'B0000DC2V5': 'Harney & Sons',
#   'B0000DC2UP': 'Harney & Sons',
#   'B0000DC2TL': 'Harney & Sons',
#   'B0000DC32J': '',
#   'B0000DC2TU': 'Harney & Sons',
#   'B0000DC2VT': 'Harney & Sons',
#   'B0000DC2U9': 'Harney & Sons',
#   'B0000DC2U7': 'Harney & Sons',
#   'B0000DC2U4': 'Harney & Sons',
#   'B0000DC2VW': 'Harney & Sons',
#   'B0000DC32S': 'Monin',
#   'B0000DC2VN': 'Harney & Sons',
#   'B0000DC324': 'Monin',
#   'B0000DC32H': 'Monin',
#   'B0000DC2TD': 'Harney & Sons',
#   'B0000DC2UR': 'Harney & Sons',
#   'B0000DC61M': 'Ka-Me',
#   'B0000DC5UH': 'Huy Fong',
#   'B0000DC2UV': 'Harney & Sons',
#   'B0000DC4OR': 'Hodgson Mill',
#   'B0000DC5UM': 'Goya',
#   'B0000DC4OV': 'Meera',
#   'B0000DC4ZR': 'MAITRE PROVI',
#   'B0000DCK36': 'ShopNatural',
#   'B0000DCWWB': '',
#   'B0000DCWYJ': 'ArtNaturals',
#   'B0000DCWW5': 'AmericanSpice.com',
#   'B0000DCWT7': '',
#   'B0000DCX9C': 'ROI',
#   'B0000DCX95': 'Daniele Devalle',
#   'B0000DCXDH': 'Pasta di Gragnano',
#   'B0000DCXCM': 'A.G. Ferrari',
#   'B0000DCX96': 'Daniele Devalle',
#   'B0000DCKGI': 'Bulk Grains',
#   'B0000DCWZA': 'Varies',
#   'B0000DCXDL': 'Tanda e Spada',
#   'B0000DCXBQ': 'Caricato',
#   'B0000DCXC8': 'Pedroni',
#   'B0000DCXES': 'A.G. Ferrari',
#   'B0000DCKCN': 'Bulk-Varies',
#   'B0000DCXF3': 'Vanini Osvaldo',
#   'B0000DCXHH': 'Baratti & Milano',
#   'B0000DCXBH': 'La Nicchia',
#   'B0000DCXAE': 'Giacomo Santoleri',
#   'B0000DCYLK': 'A.G. Ferrari',
#   'B0000DCXFY': 'A.G. Ferrari',
#   'B0000DCXEU': 'A.G. Ferrari',
#   'B0000DCYML': 'A.G. Ferrari',
#   'B0000DCYMX': 'TartufLanghe',
#   'B0000DCYM6': 'Pedroni',
#   'B0000DCXDQ': 'Mulino Sobrino',
#   'B0000DCYLF': 'A.G. Ferrari',
#   'B0000DCYM0': 'A.G. Ferrari',
#   'B0000DCYMK': 'Giammona',
#   'B0000DCYN9': 'Fieschi',
#   'B0000DCXG2': 'A.G. Ferrari',
#   'B0000DCXH0': 'Rizzoli',
#   'B0000DCXGJ': 'Leone',
#   'B0000DCYLG': 'A.G. Ferrari',
#   'B0000DCWWI': "Dave's Gourmet",
#   'B0000DCXDR': 'De Col Piras',
#   'B0000DD8PB': '',
#   'B0000DD8XD': 'Jellybean Foods',
#   'B0000DD8YP': '',
#   'B0000DD8YC': '',
#   'B0000DD8RB': 'Jellybean Foods',
#   'B0000DD8ZK': '',
#   'B0000DD8X7': '',
#   'B0000DDSCE': 'Tazzina',
#   'B0000DDSDX': 'Tazzina',
#   'B0000DDSC9': 'Tazzina',
#   'B0000DDSDQ': 'Tazzina',
#   'B0000DDSDT': 'Tazzina',
#   'B0000DF44M': '',
#   'B0000DF3VT': '',
#   'B0000DF3WM': 'Mrs. Wages',
#   'B0000DF3WB': 'Great American Spice Co.',
#   'B0000DF3IZ': '',
#   'B0000DFZNX': 'eBabka.com',
#   'B0000DF3M8': "Smokin' Joe Jones Barbeque & Dippin' Sauce Co.",
#   'B0000DF43M': 'AmericanSpice.com',
#   'B0000DF3FC': '',
#   'B0000DG4B1': '',
#   'B0000DG4MK': 'Sauce Crafters Direct',
#   'B0000DG4NL': 'Pyromania',
#   'B0000DG4NM': 'Baron',
#   'B0000DG4NE': 'Acid Rain Hatari',
#   'B0000DG53R': 'Iguana',
#   'B0000DG4M6': 'AmericanSpice.com',
#   'B0000DG54Z': '',
#   'B0000DG55X': "ASS KICKIN'",
#   'B0000DG55O': 'AmericanSpice.com',
#   'B0000DG4MU': 'Screaming Sphincter',
#   'B0000DG56A': 'AmericanSpice.com',
#   'B0000DG553': 'AmericanSpice.com',
#   'B0000DG573': 'Mo Hotta Mo Betta',
#   'B0000DG55M': 'Unknown',
#   'B0000DG55U': 'Figeroua Brothers',
#   'B0000DG54W': '',
#   'B0000DG57D': 'Pain is Good',
#   'B0000DG54P': '',
#   'B0000DG4MX': 'Figeroua Brothers',
#   'B0000DG57K': 'AmericanSpice.com',
#   'B0000DG5AA': 'John Boy and Billy',
#   'B0000DG4M3': 'Wing-Time',
#   'B0000DG5AP': 'Pain Is Good',
#   'B0000DG55R': "Matouk's",
#   'B0000DG5BQ': '',
#   'B0000DG55K': 'Captain Red Beards',
#   'B0000DG5AO': 'Pain Is Good',
#   'B0000DG5BN': 'AmericanSpice.com',
#   'B0000DG58W': 'Blair Q',
#   'B0000DG5CE': 'Kauffman',
#   'B0000DG4ML': 'Screaming Sphincter',
#   'B0000DG567': 'AmericanSpice.com',
#   'B0000DG59Q': '7.1 Million Scoville Units',
#   'B0000DG5AN': 'Gator Hammock',
#   'B0000DG5E7': 'Jake and Amos',
#   'B0000DG5C7': "Kauffman's",
#   'B0000DG56P': 'Original Juan',
#   'B0000DG588': 'Bayou Sauce',
#   'B0000DG5BP': '',
#   'B0000DG55L': "ASS KICKIN'",
#   'B0000DG5ED': 'Sauce Crafters Direct',
#   'B0000DG5B6': "Bone Suckin'",
#   'B0000DG5BV': 'Golden Barrel',
#   'B0000DG57P': "Porky's",
#   'B0000DG5CF': "Pappy's",
#   'B0000DG5EE': 'Stadium Mustard',
#   'B0000DG5AF': '',
#   'B0000DG55I': 'CaJohns Fiery Foods',
#   'B0000DG6WL': 'Wisconsinmade',
#   'B0000DG6Y0': 'Wisconsinmade',
#   'B0000DG58T': '',
#   'B0000DG4MS': 'Great American Spice Co',
#   'B0000DG5A8': 'AmericanSpice.com',
#   'B0000DG5AB': 'Gator Hammock',
#   'B0000DG71N': 'Wisconsinmade',
#   'B0000DG6ZW': 'The Gift Basket Gallery',
#   'B0000DG71T': 'Wisconsinmade',
#   'B0000DG5CD': 'Organic Herbal Essence',
#   'B0000DG87B': "Brussel's Bonsai",
#   'B0000DG737': 'Wisconsinmade',
#   'B0000DG8AQ': "Brussel's Bonsai",
#   'B0000DG871': "Brussel's Bonsai",
#   'B0000DG57Q': "Pappy's",
#   'B0000DG72O': 'Wisconsinmade',
#   'B0000DG6WN': 'Wisconsinmade',
#   'B0000DG8AR': "Brussel's Bonsai",
#   'B0000DGD7O': 'Extra',
#   'B0000DG86X': "Brussel's Bonsai",
#   'B0000DGD7Q': 'Extra Gum',
#   'B0000DGDPF': 'Spearmint',
#   'B0000DGF5P': "Brussel's Bonsai",
#   'B0000DGEOW': 'Cape Tea',
#   'B0000DGFEE': "Brussel's Bonsai",
#   'B0000DGF5U': "Brussel's Bonsai",
#   'B0000DGG22': "Brussel's Bonsai",
#   'B0000DGFCO': "Brussel's Bonsai",
#   'B0000DGG51': "Brussel's Bonsai",
#   'B0000DGG4Y': "Brussel's Bonsai",
#   'B0000DGENZ': 'Cape Tea',
#   'B0000DGG89': "Brussel's Bonsai",
#   'B0000DG5EC': 'Frank',
#   'B0000DGG8B': "Brussel's Bonsai",
#   'B0000DGDOI': 'Orbit Gum',
#   'B0000DGFCS': "Brussel's Bonsai",
#   'B0000DGFCL': "Brussel's Bonsai",
#   'B0000DGG24': "Brussel's Bonsai",
#   'B0000DGFA5': "Brussel's Bonsai",
#   'B0000DGF9V': "Brussel's Bonsai",
#   'B0000DGGMI': 'Ghirardelli',
#   'B0000DGFCW': "Brussel's Bonsai",
#   'B0000DI0OE': 'Prince Of Peace',
#   'B0000DHZCG': 'Modern Products Flavorings',
#   'B0000DI085': 'Simply Organic',
#   'B0000DHZCO': 'Modern Products Flavorings',
#   'B0000DHXGL': 'Food to Live',
#   'B0000DHXLY': 'Lundberg',
#   'B0000DHZOA': 'Frontier',
#   'B0000DHZZB': 'Frontier',
#   'B0000DI0EX': '',
#   'B0000DHXGI': 'Its Delish',
#   'B0000DI145': 'Celestial Seasonings',
#   'B0000DI1IG': 'Celestial Seasonings',
#   'B0000DHXAK': 'Varies',
#   'B0000DHZT8': 'Frontier',
#   'B0000DI0KA': 'Plantation Molasses',
#   'B0000DHZY1': 'Frontier',
#   'B0000DI1E8': "Uncle Lee's",
#   'B0000DI1EC': "Uncle Lee's Tea",
#   'B0000DI0GU': '',
#   'B0000DHZ3W': 'Thai Kitchen',
#   'B0000DIC1N': '',
#   'B0000DID5S': "Dave's Gourmet",
#   'B0000DID5R': "Dave's Gourmet",
#   'B0000DID5W': "Dave's Gourmet",
#   'B0000DID5X': "Dave's Gourmet",
#   'B0000DID62': "Dave's Gourmet",
#   'B0000DID6A': 'Unknown',
#   'B0000DID7E': 'Reber',
#   'B0000DID64': "Dave's Gourmet",
#   'B0000DID63': "Dave's Gourmet",
#   'B0000DID7I': 'Reber Chocolate Specialties',
#   'B0000DID7D': 'Reber Chocolate Specialties',
#   'B0000DID77': 'Reber',
#   'B0000DID78': 'Reber Chocolate Specialties',
#   'B0000DID7A': 'Reber Chocolate Specialties',
#   'B0000DID6E': "Dave's Gourmet",
#   'B0000DIFMY': 'Peloponnese',
#   'B0000DID6T': "Dave's Gourmet",
#   'B0000DID7M': 'Reber Chocolate Specialties',
#   'B0000DIEJ1': 'Enrico Formella',
#   'B0000DIFWS': 'Goya',
#   'B0000DIPJC': 'Hachez',
#   'B0000DIPJA': 'Hachez Chocolatier',
#   'B0000DISUY': 'Candy4u',
#   'B0000DIRZS': 'Candy4u',
#   'B0000DISV6': 'Candy4u',
#   'B0000DISV9': 'Candy4u',
#   'B0000DIRZR': 'Candy4u',
#   'B0000DIVU9': 'Jaret',
#   'B0000DISV7': 'Candy4u',
#   'B0000DISV4': 'Candy4u',
#   'B0000DIPMM': 'McCormick',
#   'B0000DIVU7': 'Jaret',
#   'B0000DIWKP': 'J&D Fine Foods',
#   'B0000DIVUB': 'Jaret',
#   'B0000DIWKH': 'J&D Fine Foods',
#   'B0000DIWR3': 'Rock Candy',
#   'B0000DIWKM': 'J&D Fine Foods',
#   'B0000DIWWD': "Blair's",
#   'B0000DIWWE': "Blair's",
#   'B0000DIWIQ': 'J&D Fine Foods',
#   'B0000DIX2Y': 'Blairs Sauces',
#   'B0000DIX2U': "Blair's",
#   'B0000DIQG9': 'Pernigotti',
#   'B0000DIX32': "Blair's",
#   'B0000DIXKS': 'Alaska Smokehouse',
#   'B0000DIXKU': 'Alaska Smokehouse',
#   'B0000DIYI7': 'Trolli',
#   'B0000DISV8': 'Candy4u',
#   'B0000DIYIJ': 'Candy4u',
#   'B0000DIYK1': "Gimbal's",
#   'B0000DIYK6': "Kenny's",
#   'B0000DIYK3': 'Goelitz',
#   'B0000DIYK0': "Gimbal's",
#   'B0000DIYKE': '',
#   'B0000DIYIF': 'Candy4u',
#   'B0000DIYW7': 'Jelly Belly',
#   'B0000DIYW1': 'Jelly Belly',
#   'B0000DIYVM': 'Jelly Belly',
#   'B0000DIYUP': 'Jelly Belly',
#   'B0000DIYUV': 'Jelly Belly',
#   'B0000DIYWF': 'Jelly Belly',
#   'B0000DIYII': 'Haribo',
#   'B0000DIYWB': 'Jelly Belly',
#   'B0000DIYIG': 'Candy4u',
#   'B0000DIYWO': 'Jelly Belly',
#   'B0000DIYK7': "Kenny's",
#   'B0000DIYUT': 'Jelly Belly',
#   'B0000DIYU6': 'Jelly Belly',
#   'B0000DIYIL': 'Trolli',
#   'B0000DIYWZ': 'Jelly Belly',
#   'B0000DIYVQ': 'Jelly Belly',
#   'B0000DJ7TY': 'Omaha Steaks',
#   'B0000DJ7TL': 'Omaha Steaks',
#   'B0000DIYKF': "Bassett's",
#   'B0000DJ7SX': 'Omaha Steaks',
#   'B0000DJ7W5': 'Omaha Steaks',
#   'B0000DJ7Z6': 'Omaha Steaks',
#   'B0000DIYVO': 'Jelly Belly',
#   'B0000DJ7XE': 'Omaha Steaks',
#   'B0000DJ88P': 'Omaha Steaks',
#   'B0000DJ81T': 'Omaha Steaks',
#   'B0000DIYUX': 'Jelly Belly',
#   'B0000DJ7XG': 'Omaha Steaks',
#   'B0000DJ7SR': 'Omaha Steaks',
#   'B0000DJ6NI': 'Tootsie Roll',
#   'B0000DJ7VQ': 'Omaha Steaks',
#   'B0000DJ7SD': 'Omaha Steaks',
#   'B0000DJ7SA': 'Omaha Steaks',
#   'B0000DJ7YW': 'Omaha Steaks',
#   'B0000DJ7YT': 'Omaha Steaks',
#   'B0000DJ89S': 'Omaha Steaks',
#   'B0000DJ89O': 'Omaha Steaks',
#   'B0000DJ6NG': 'Tootsie Roll',
#   'B0000DJ7T0': 'Omaha Steaks',
#   'B0000DJ85D': '',
#   'B0000DJ81R': 'Omaha Steaks',
#   'B0000DJ89Q': 'Omaha Steaks',
#   'B0000DJDHJ': "Joseph's Lite Cookies",
#   'B0000DJDJX': '',
#   'B0000DJDL4': 'O&H Danish Bakery',
#   'B0000DJDHN': "Joseph's Lite Cookies",
#   'B0000DJFG8': "Mustapha's Moroccan",
#   'B0000DJETH': "Mustapha's Moroccan",
#   'B0000DJESD': "Mustapha's Moroccan",
#   'B0000DJFDY': "Mustapha's Moroccan",
#   'B0000DJF59': "Mustapha's Moroccan",
#   'B0000DJT4I': 'Concord Confections',
#   'B0000DJT38': 'Candy4u',
#   'B0000DJT1J': 'Jaret',
#   'B0000DK2WM': 'Cheese Express',
#   'B0000DK39I': 'Cheese Express',
#   'B0000DK4E0': 'Get Suckered Etc,',
#   'B0000DK4G4': 'Get Suckered Etc,',
#   'B0000DK463': 'Cheese Express',
#   'B0000DK3Z1': 'Cheese Express',
#   'B0000DK4J0': 'Get Suckered Etc,',
#   'B0000DK527': 'Cheese Express',
#   'B0000DK5KE': 'Get Suckered Etc,',
#   'B0000DK59J': 'Cheese Express',
#   'B0000DK59A': 'Get Suckered Etc,',
#   'B0000DK56B': 'Get Suckered Etc,',
#   'B0000DK36Z': 'Cheese Express',
#   'B0000DK5JJ': 'Get Suckered Etc,',
#   'B0000DK5SQ': 'Get Suckered Etc,',
#   'B0000DK5RS': 'Get Suckered Etc,',
#   'B0000DK4WM': 'Get Suckered Etc,',
#   'B0000DK5DR': 'Get Suckered Etc,',
#   'B0000DK5WY': 'Get Suckered Etc,',
#   'B0000DK4SL': 'Cheese Express',
#   'B0000DK671': 'Get Suckered Etc,',
#   'B0000DK43R': 'Get Suckered Etc,',
#   'B0000DK92B': 'Get Suckered Etc,',
#   'B0000DK95R': 'Get Suckered Etc,',
#   'B0000DK6UV': 'Get Suckered Etc.',
#   'B0000DK6DL': 'Get Suckered Etc,',
#   'B0000DK6KB': 'Cheese Express',
#   'B0000DK9WZ': 'Get Suckered Etc,',
#   'B0000DK9YW': 'Get Suckered Etc,',
#   'B0000DK6XP': 'Get Suckered Etc,',
#   'B0000DKBS4': 'Get Suckered Etc,',
#   'B0000DK917': 'Get Suckered Etc,',
#   'B0000DKA6J': 'Get Suckered Etc,',
#   'B0000DK6IV': 'Cheese Express',
#   'B0000DK97W': 'Get Suckered Etc,',
#   'B0000DKBH3': 'Get Suckered Etc,',
#   'B0000DK9NS': 'Get Suckered Etc,',
#   'B0000DK9W4': 'Get Suckered Etc,',
#   'B0000DK6PO': 'Get Suckered Etc,',
#   'B0000DKB71': 'Get Suckered Etc,',
#   'B0000DK6K5': 'Cheese Express',
#   'B0000DK6P5': 'Get Suckered Etc,',
#   'B0000DK6UD': 'Get Suckered Etc,',
#   'B0000DKQ59': 'Nielsen-Massey',
#   'B0000DK9VS': 'Get Suckered Etc,',
#   'B0000DK9QU': 'Get Suckered Etc,',
#   'B0000DYGAF': 'The BEST Cheesecake on the Planet!',
#   'B0000DYNFH': 'Frontier Soups',
#   'B0000DYNFC': 'Frontier Soups',
#   'B0000DYNFF': 'Frontier Soups',
#   'B0000DYNFN': 'Frontier Soups',
#   'B0000DYZC1': 'Clubs of America - Monthly Gift Clubs',
#   'B0000DZ0Q6': 'Clubs of America - Monthly Gift Clubs',
#   'B0000DYZCA': 'Clubs of America - Monthly Gift Clubs',
#   'B0000DYVMJ': 'Candy4u',
#   'B0000DZ0Q3': 'Clubs of America - Monthly Gift Clubs',
#   'B0000DYZBN': 'Clubs of America',
#   'B0000DZ0PP': 'Clubs of America - Monthly Gift Clubs',
#   'B0000DZ0Q4': 'Clubs of America - Monthly Gift Clubs',
#   'B0000DZBO3': 'Mocafe',
#   'B0000DZC7E': 'Big Acres Gourmet Foods',
#   'B0000DZEV2': 'Palacios',
#   'B0000DZCFS': 'Big Acres',
#   'B0000DZLTG': 'Candy4u',
#   'B0000DZEYP': '',
#   'B0000DZLTY': 'Candy4u',
#   'B0000E1VU8': 'Peppers',
#   'B0000E1VRX': 'Il Primo',
#   'B0000E1VUG': 'AmericanSpice.com',
#   'B0000E224F': 'Gevalia',
#   'B0000E222W': 'Gevalia',
#   'B0000E221W': 'Gevalia',
#   'B0000E223C': 'Gevalia',
#   'B0000E2EOU': 'Madelaine Chocolate Company',
#   'B0000E21YI': 'Gevalia',
#   'B0000E227B': 'Gevalia',
#   'B0000E2EOV': 'Madelaine Chocolate Company',
#   'B0000E2EPD': 'Primrose Candy Company',
#   'B0000E227M': 'Gevalia',
#   'B0000E21ZU': 'Gevalia',
#   'B0000E2EP0': 'Peerless Confection Co.',
#   'B0000E21XE': 'Gevalia',
#   'B0000E21Y2': 'Gevalia',
#   'B0000E2FI0': 'Gold Medal',
#   'B0000E2PX6': 'Maggi',
#   'B0000E2EP4': 'Peerless Confection Co.',
#   'B0000E2T6F': 'Oak Leaf Confections',
#   'B0000E2T5X': 'Oak Leaf Confections',
#   'B0000E2T69': 'Oak Leaf Confections',
#   'B0000E2T63': 'Oak Leaf Confections',
#   'B0000E2T62': 'Oak Leaf Confections',
#   'B0000E2T68': 'Oak Leaf Confections',
#   'B0000E2T6E': 'Oak Leaf Confections',
#   'B0000E2T64': 'Oak Leaf Confections',
#   'B0000E2YA0': 'Wonka',
#   'B0000E2Y9T': 'Wonka',
#   'B0000E2YA1': 'Wonka',
#   'B0000E2Y9K': 'Laffy Taffy',
#   'B0000E2Y9O': 'Laffy Taffy',
#   'B0000E2Y6J': 'Oak Leaf Confections',
#   'B0000E2YFI': 'Charms',
#   'B0000E2Y9X': 'Wonka',
#   'B0000E5IHG': 'Harney & Sons',
#   'B0000E5JID': 'TABASCO brand',
#   'B0000E5JI4': 'TABASCO brand',
#   'B0000E5IGB': 'Harney & Sons',
#   'B0000E5IH6': 'Harney & Sons',
#   'B0000E5JIU': 'Cafe Du Monde',
#   'B0000E5JK7': 'Luzianne',
#   'B0000E5JJD': 'R.M. QUIGGS Herb Rice Mix',
#   'B0000E5JM2': "ZATARAIN'S Southern Chicken Fry Mix",
#   'B0000E5JLJ': "ZATARAIN'S Lemon Shrimp & Crab Boil",
#   'B0000E5JK8': 'Luzianne',
#   'B0000E5JKD': 'Luzianne',
#   'B0000E5IHL': 'Harney & Sons',
#   'B0000E5JN9': 'Falcon Popcorn Rice',
#   'B0000E5JKC': 'Coffee Partner',
#   'B0000E5JOT': 'LOUISIANA Chicken Fry (Seasoned)',
#   'B0000E5JOC': "Tony Chachere's Salt Free Creole Seasoning",
#   'B0000E5JPE': 'Cajun Injector',
#   'B0000E5JIZ': 'Konriko',
#   'B0000E5JQ5': 'Louisiana Jalapeno Hot Sauce',
#   'B0000E5JP1': 'LOUISIANA Tartar Sauce',
#   'B0000E5JRL': 'Cajun Chef',
#   'B0000E5JM4': "Zatarain's",
#   'B0000E5JPA': 'Crystal Original Wing Sauce',
#   'B0000E5JL5': "Zatarain's",
#   'B0000E5JNR': "Grandma Rena's Rabbit & Squirrel Seasoning",
#   'B0000E5JKV': "Zatarain's",
#   'B0000E5JJ2': 'Konriko',
#   'B0000E5JRO': 'Cajun Chef',
#   'B0000E5JNB': "Ellis Stansel's Gourmet Rice",
#   'B0000E5JX3': 'Chef John Folse Seafood Gumbo',
#   'B0000E5JMD': 'REX Tarragon',
#   'B0000E5L18': 'Harney & Sons',
#   'B0000E5KZR': 'Harney & Sons',
#   'B0000E5L3U': 'Harney & Sons',
#   'B0000E5JLT': "Zatarain's",
#   'B0000E5JO4': 'Boscoli',
#   'B0000E5JRZ': 'Camellia',
#   'B0000E5JT4': 'Fresh Alligator Sausage w/ Pork (Farm Pride)',
#   'B0000E5JQ1': '`LOUISIANA',
#   'B0000E5JRX': 'Camellia',
#   'B0000E5L0J': 'Harney & Sons',
#   'B0000E5JRS': 'Cajun Chef',
#   'B0000E5L1S': 'Harney & Sons',
#   'B0000E5JU6': "Richard's Cajun Country",
#   'B0000E5L4E': 'Harney & Sons',
#   'B0000E5JP7': 'Crystal Classic Habanero Sauce',
#   'B0000E5L3E': 'Harney & Sons',
#   'B0000E5JK9': 'Luzianne',
#   'B0000E5M9I': 'Charleston Seafood',
#   'B0000E5MA3': 'Charleston Seafood',
#   'B0000E5JLQ': "ZATARAIN'S Remoulade Sauce",
#   'B0000E5JM6': "ZATARAIN'S Salmon Cake Mix",
#   ...}}

# %% [markdown]
# ### brand 매핑

# %%
itemid_to_brand = {}
for itemid, brand in items_meta['item2brand'].items():
    itemid_to_brand[itemid] = brand

df['brand']=df['asin'].map(itemid_to_brand)
df
# Out:
#                 user_id        asin   timestamp          brand
# 0        A1QVBUH9E1V6I8  4639725183  1416355200         Lipton
# 1        A3GEOILWLK86XM  4639725183  1476316800         Lipton
# 2        A32RD6L701BIGP  4639725183  1448064000         Lipton
# 3        A2UY1O1FBGKIE6  4639725183  1439337600         Lipton
# 4        A3QHVBQYDV7Z6U  4639725183  1432771200         Lipton
# ...                 ...         ...         ...            ...
# 1143855  A223YRQH2Z5T1D  B01HJF6FRA  1504828800  Hampton Creek
# 1143856  A38GDA4TB9EILT  B01HJF6FRA  1501804800  Hampton Creek
# 1143857  A2025PN7HDC5BO  B01HJF6FRA  1499126400  Hampton Creek
# 1143858  A1NY7XWC7EPQOA  B01HJF6FRA  1496793600  Hampton Creek
# 1143859  A1P0X9E6F99J4T  B01HJF6FRA  1495238400  Hampton Creek
#
# [1143860 rows x 4 columns]

# %% [markdown]
# ### category 매핑

# %%
itemid_to_category = {}
for itemid, category in items_meta['item2category'].items():
    itemid_to_category[itemid] = category

df['category']=df['asin'].map(itemid_to_category)
df
# Out:
#                 user_id        asin   timestamp          brand  \
# 0        A1QVBUH9E1V6I8  4639725183  1416355200         Lipton
# 1        A3GEOILWLK86XM  4639725183  1476316800         Lipton
# 2        A32RD6L701BIGP  4639725183  1448064000         Lipton
# 3        A2UY1O1FBGKIE6  4639725183  1439337600         Lipton
# 4        A3QHVBQYDV7Z6U  4639725183  1432771200         Lipton
# ...                 ...         ...         ...            ...
# 1143855  A223YRQH2Z5T1D  B01HJF6FRA  1504828800  Hampton Creek
# 1143856  A38GDA4TB9EILT  B01HJF6FRA  1501804800  Hampton Creek
# 1143857  A2025PN7HDC5BO  B01HJF6FRA  1499126400  Hampton Creek
# 1143858  A1NY7XWC7EPQOA  B01HJF6FRA  1496793600  Hampton Creek
# 1143859  A1P0X9E6F99J4T  B01HJF6FRA  1495238400  Hampton Creek
#
#                                                   category
# 0        [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 1        [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 2        [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 3        [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 4        [Grocery & Gourmet Food, Beverages, Coffee, Te...
# ...                                                    ...
# 1143855  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 1143856  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 1143857  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 1143858  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 1143859  [Grocery & Gourmet Food, Condiments & Salad Dr...
#
# [1143860 rows x 5 columns]

# %% [markdown]
# ### userid, timestamp 순으로 정렬

# %%
df= df.sort_values(by=['user_id', 'timestamp'])

# %%
df
# Out:
#                       user_id        asin   timestamp                  brand  \
# 402831   A0096681Y127OL1H8W3U  B002UGMH9Y  1425513600         Big Tree Farms
# 209596   A0096681Y127OL1H8W3U  B0013OX8II  1435104000                 Jarrow
# 263297   A0096681Y127OL1H8W3U  B0013OX8II  1435104000                 Jarrow
# 570023   A0096681Y127OL1H8W3U  B006RNQ7YW  1435104000          Dr. Bronner's
# 111001   A0096681Y127OL1H8W3U  B000HDI5O8  1493769600  Farmer's Market Foods
# ...                       ...         ...         ...                    ...
# 588636          AZZZ5UJWUVCYZ  B007IS64J8  1505865600           Ice Breakers
# 848720          AZZZ5UJWUVCYZ  B00LPF63DW  1505865600                 Atkins
# 1135281         AZZZ5UJWUVCYZ  B0147QHDKM  1505865600               Halo Top
# 1143594         AZZZ5UJWUVCYZ  B01H2R5IT6  1505865600              Wang Derm
# 1024801         AZZZ5UJWUVCYZ  B000CQIDJM  1521676800              Stash Tea
#
#                                                   category
# 402831   [Grocery & Gourmet Food, Cooking & Baking, Sug...
# 209596   [Grocery & Gourmet Food, Cooking & Baking, Coo...
# 263297   [Grocery & Gourmet Food, Cooking & Baking, Coo...
# 570023   [Grocery & Gourmet Food, Cooking & Baking, Coo...
# 111001   [Grocery & Gourmet Food, Cooking & Baking, Pie...
# ...                                                    ...
# 588636   [Grocery & Gourmet Food, Candy & Chocolate, Mi...
# 848720         [Grocery & Gourmet Food, Candy & Chocolate]
# 1135281  [Grocery & Gourmet Food, Frozen, Ice Cream & N...
# 1143594  [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 1024801  [Grocery & Gourmet Food, Beverages, Coffee, Te...
#
# [1143860 rows x 5 columns]

# %% [markdown]
# ### user 별 같은 brand의 item을 구매한 주기 추출

# %% [markdown]
# - user_reviews에 brand info mapping

# %%
user_reviews_brand = defaultdict(list)

# user_reviews 딕셔너리를 데이터프레임으로 변환
user_reviews_df = pd.DataFrame([(user, itemid, timestamp) for user, interactions in user_reviews.items() for itemid, timestamp in interactions], columns=['user_id', 'asin', 'timestamp'])

# user_id, asin, timestamp를 기준으로 df와 조인
merged_df = pd.merge(user_reviews_df, df, left_on=['user_id', 'asin', 'timestamp'], right_on=['user_id', 'asin', 'timestamp'], how='inner')

# user_reviews_brand 딕셔너리에 정보 추가
for index, row in merged_df.iterrows():
    user_reviews_brand[row['user_id']].append([row['asin'], row['timestamp'], row['brand']])


user_reviews_brand = defaultdict(list)

# user_reviews 딕셔너리를 순회하면서 조건에 맞는 데이터프레임 행을 필터링하여 정보 추가
for user, interactions in user_reviews.items():
    for itemid, timestamp in interactions:
        filtered_df = df[(df['user_id'] == user) & (df['asin'] == itemid) & (df['timestamp'] == timestamp)]
        for index, row in filtered_df.iterrows():
            user_reviews_brand[user].append([itemid, timestamp, row['brand']])

user_reviews_brand
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[190], line 19
#      17 for user, interactions in user_reviews.items():
#      18     for itemid, timestamp in interactions:
# ---> 19         filtered_df = df[(df['user_id'] == user) & (df['asin'] == itemid) & (df['timestamp'] == timestamp)]
#      20         for index, row in filtered_df.iterrows():
#      21             user_reviews_brand[user].append([itemid, timestamp, row['brand']])
#
# File /opt/homebrew/anaconda3/envs/modeling/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/anaconda3/envs/modeling/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /opt/homebrew/anaconda3/envs/modeling/lib/python3.11/site-packages/pandas/core/series.py:6110, in Series._cmp_method(self, other, op)
#    6107 lvalues = self._values
#    6108 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6110 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6112 return self._construct_result(res_values, name=res_name)
#
# File /opt/homebrew/anaconda3/envs/modeling/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /opt/homebrew/anaconda3/envs/modeling/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
from collections import defaultdict
import numpy as np

def calculate_purchase_intervals(interactions):
    item_period=defaultdict(list)

    for user, interactions_list in interactions.items():
        interactions_list.sort(key=lambda x: x[1])# timestamp sort

        item_count = defaultdict(int)
        item_timestamps = defaultdict(list)
    
        for item, timestamp in interactions_list:
            item_count[item] += 1
            item_timestamps[item].append(timestamp)

        
        for item, count in item_count.items():
            if count == 1:
                item_period[user].append((item, 0))

            elif count == 2:
                period = item_timestamps[item][1] - item_timestamps[item][0]
                item_period[user].append((item, period))
            else: # count>=3
                periods = []
                timestamps = item_timestamps[item]
                for i in range(len(timestamps) - 1):
                    periods.append(abs(timestamps[i + 1] - timestamps[i]))
                if periods:
                    avg_period = np.mean(periods)
                    item_period[user].append((item, avg_period))

    return item_period


calculate_purchase_intervals(user_reviews)
# Out:
# defaultdict(list,
#             {'A1QVBUH9E1V6I8': [('4639725183', 0),
#               ('B000E6LBXK', 0),
#               ('B00KC6C8M0', 0),
#               ('B004CPAP5E', 0),
#               ('B00863B5JI', 0)],
#              'A3GEOILWLK86XM': [('B001XSMANI', 0),
#               ('B009PARMMA', 0),
#               ('B000H24066', 0),
#               ('B001G7QL72', 0),
#               ('B00845B7NW', 0),
#               ('B000PWWQP0', 0),
#               ('B001M074O2', 0),
#               ('B004SKOGZI', 0),
#               ('B00374XTQI', 0),
#               ('B0091YGEJ2', 0),
#               ('B0007QMT7O', 0),
#               ('B0028667PG', 0),
#               ('B00E3A1SQS', 0),
#               ('B00006FWVX', 0),
#               ('B0000VM9EE', 0),
#               ('B004Z0K2N6', 0),
#               ('B000GFYRHQ', 0),
#               ('B01C4N8ICC', 0),
#               ('4639725183', 0)],
#              'A32RD6L701BIGP': [('B000ES5GMK', 0),
#               ('B005S8XXW6', 0),
#               ('B0074LM402', 0),
#               ('B0093NRWPG', 0),
#               ('B001XSMANI', 0),
#               ('B00QEF9IBM', 0),
#               ('B0036IPF0I', 0),
#               ('B00ICPZ75I', 0),
#               ('B00JOK1VBE', 0),
#               ('B0001LO3FG', 0),
#               ('B000F4DKAI', 0),
#               ('B0010L50GC', 0),
#               ('4639725183', 0),
#               ('B000CRIUNU', 0),
#               ('B000VK2KWK', 0),
#               ('B003OB4BOS', 0),
#               ('B00DDYANU2', 0),
#               ('B001R598NW', 0),
#               ('B01E89YPDQ', 0),
#               ('B01H4EG2SS', 0),
#               ('B000FB1XGY', 0),
#               ('B001E2TAX6', 0),
#               ('B002707WIY', 0),
#               ('B00IV2ZU9K', 0)],
#              'A2UY1O1FBGKIE6': [('B001COJ860', 0),
#               ('B000JSQDK4', 0),
#               ('B002E0S506', 0),
#               ('4639725183', 0),
#               ('B003OGKCDC', 0),
#               ('B004XDMS3C', 0),
#               ('B0032JWE28', 0),
#               ('B006CQ1ZHI', 0)],
#              'A3QHVBQYDV7Z6U': [('B004RDVGQS', 0),
#               ('B005DVIK30', 0),
#               ('4639725183', 0),
#               ('B00UU28UGE', 0),
#               ('B004ZEN590', 0),
#               ('B00CJ6NB3Q', 0),
#               ('B01EIA2YXI', 0)],
#              'A14MJZP7H1KHEX': [('4639725183', 0),
#               ('B000NIFO96', 0),
#               ('B00CID1BS2', 0),
#               ('B00KGJM0RG', 0),
#               ('B00EKL415U', 0)],
#              'A32CQJQBV7YRT': [('4639725183', 0),
#               ('B007BENTO2', 0),
#               ('B00C43N80U', 0),
#               ('B001DC9SY8', 0),
#               ('B001F35WSQ', 0),
#               ('B00DEJZMPW', 0),
#               ('B001688TI0', 0),
#               ('B01BZ5U3Y6', 0),
#               ('B00O1QQXLY', 0),
#               ('B009A48I1U', 0)],
#              'A2EUMXCQHCP25R': [('B000G1PAC6', 0),
#               ('B0016BCEE2', 0),
#               ('B0057PVGU6', 0),
#               ('4639725183', 0),
#               ('B00014HS2S', 0),
#               ('B0016BFR4G', 0),
#               ('B00ZV8RODW', 0)],
#              'A3QD1PUOO5I94A': [('B001MGEU0W', 0),
#               ('B002BLIT7C', 0),
#               ('4639725183', 0),
#               ('B001THW7AO', 0),
#               ('B000QC406C', 0),
#               ('B00AIR3Q38', 0)],
#              'A9E9L159FFMHP': [('B000HIFANW', 0),
#               ('B000LQLV6U', 0),
#               ('B001EQ5D42', 0),
#               ('4639725183', 0),
#               ('B0001M0Z6Q', 0),
#               ('B000EVN2ZK', 0),
#               ('B00B9EMU9U', 0),
#               ('B00D5XU33S', 0),
#               ('B00T3U082S', 0)],
#              'A1B65ENXWAN2SB': [('4639725183', 0),
#               ('B004TJF39Q', 0),
#               ('B005K4Q37U', 0),
#               ('B005K4Q1T0', 0),
#               ('B007OWVOQQ', 0)],
#              'A1J205ZK25TZ6W': [('B002EAPHKM', 0),
#               ('4639725043', 0),
#               ('B000EM6PC6', 0),
#               ('B00542YXFW', 0),
#               ('B000PGA8WY', 0),
#               ('B002AWXELI', 0),
#               ('B001N2GRX8', 0),
#               ('B006E0NDFO', 0),
#               ('B00XABKAWY', 0),
#               ('B00BPNZIEY', 0),
#               ('B00JV21X2W', 0),
#               ('B00D5L0UEW', 0),
#               ('B00OBU70PS', 0),
#               ('B000E1FZHS', 0),
#               ('B000U0OUP6', 0),
#               ('B00KQ10D1Y', 0),
#               ('B00RW0MZ6S', 0),
#               ('B00XOORKRK', 0),
#               ('B00WXZJTS4', 0),
#               ('B00X904XQK', 0),
#               ('B000GW0U9I', 0),
#               ('B00FFJ2GRG', 0),
#               ('B005CD3JG2', 0),
#               ('B004CVDV3Q', 0),
#               ('B005EL1D1A', 0)],
#              'ACOICLIJQYECU': [('B00542YXFW', 0),
#               ('4639725043', 0),
#               ('B001E5DRH8', 0),
#               ('B000H7F5IS', 0),
#               ('B005EL6VOY', 0)],
#              'A29RCQA5G0B1BA': [('B00AR6NBU8', 0),
#               ('B00GA95AV4', 0),
#               ('B00886E4K0', 0),
#               ('B00028MOQS', 0),
#               ('B000NGRUQ8', 0),
#               ('B00712N6II', 0),
#               ('B0001M0Z6Q', 0),
#               ('B00CMQD3VS', 0),
#               ('B000QYGCYI', 0),
#               ('B00FLXP9MU', 0),
#               ('B00XCLF5MC', 0),
#               ('B001FVQI54', 0),
#               ('B00099XK6I', 0),
#               ('4639725043', 0)],
#              'A34KF6WKUMO0G5': [('B003SPO3FC', 0),
#               ('B003V8E5ZE', 0),
#               ('B006CNTR6W', 0),
#               ('4639725043', 0),
#               ('B000YF4PZW', 0)],
#              'A2AW00VDYVKKKK': [('B000LKWTJY', 0),
#               ('B000NIHZMU', 0),
#               ('B00VLOCBHE', 0),
#               ('B014WCN60M', 0),
#               ('4639725043', 0),
#               ('B00CPBS2E8', 0),
#               ('B014GLC2LS', 0),
#               ('B00CA6RE8S', 0),
#               ('B00M59AHAC', 0)],
#              'A2LNL6MN1OEXAM': [('B00271OPVU', 0),
#               ('B00U132KQ8', 0),
#               ('B003KQSMOW', 0),
#               ('B003ZXCA2U', 0),
#               ('B00451W2ZG', 0),
#               ('B005C1GRRM', 0),
#               ('B00C3YAH5E', 0),
#               ('B00OOVPDWG', 0),
#               ('B00NFVPQ9G', 0),
#               ('B011J4CGFC', 0),
#               ('B0015GSB9U', 0),
#               ('B009LIVYNY', 0),
#               ('B009PIILEK', 0),
#               ('B01BW10140', 0),
#               ('B001GQ9YJ0', 0),
#               ('B00BMYXFFK', 0),
#               ('B00E0WB292', 0),
#               ('B01898YHXK', 0),
#               ('B00Q4OL47O', 0),
#               ('B00QU781RG', 0),
#               ('4639725043', 0),
#               ('B005IC2Q70', 0),
#               ('B00CJLPVT8', 0),
#               ('B00PQ540FU', 0),
#               ('B001CHFSR0', 0),
#               ('B004M3IXZU', 0)],
#              'A32TZ4HWVHBYX7': [('B000AYDHYW', 0),
#               ('B0000CH4GM', 0),
#               ('B004SIAPQY', 0),
#               ('B00542YXFW', 0),
#               ('B005TXW4SO', 0),
#               ('B00LAY3NTA', 0),
#               ('4639725043', 0),
#               ('B00HZ8SVI8', 0)],
#              'A2AGPIWL0G3UQR': [('B00CY0RRAK', 0),
#               ('B001VIIXXQ', 0),
#               ('B000HRS7OM', 0),
#               ('4639725043', 0),
#               ('B00099XK6I', 0)],
#              'A2PMV21JFDKJIU': [('B000I552GE', 0),
#               ('B000ZMEWNO', 0),
#               ('B001EQ5RO8', 0),
#               ('B005PNMTEW', 0),
#               ('B002O19HWU', 0),
#               ('B001H803P6', 0),
#               ('B007NLZA7M', 0),
#               ('B00HGJ9M9I', 0),
#               ('B0028QU45U', 0),
#               ('B00AXBVRXU', 0),
#               ('B001KUWCZ0', 0),
#               ('B002FYI80S', 0),
#               ('B001H828EK', 0),
#               ('4639725043', 0),
#               ('B00QHDALRQ', 0)],
#              'A1WWHO8B64HCLN': [('4639725043', 0),
#               ('B000FFIL60', 0),
#               ('B001VIIXXQ', 0),
#               ('B00542YXFW', 0),
#               ('B00GRYR9IO', 0),
#               ('B00136MKEO', 0.0)],
#              'A3ALL8JW7604P7': [('4639725043', 0),
#               ('B000HRS7OM', 0),
#               ('B000JSSNW0', 0),
#               ('B00542YXFW', 0),
#               ('B0014E4G0Q', 0),
#               ('B0025UCIGC', 0),
#               ('B00MA5N78K', 0)],
#              'A1A5GOE5E7BL9S': [('B004VLV7NS', 0),
#               ('B001VIEZLK', 0),
#               ('B00EVQL5A8', 0),
#               ('B001EQ54K0', 0),
#               ('B00JTFIF22', 0),
#               ('B000S75D66', 0),
#               ('4639725043', 0),
#               ('B00099XK6I', 0),
#               ('B001QTRGAQ', 0),
#               ('B0047487TG', 0),
#               ('B00HJNTII6', 0),
#               ('B005GLXRC6', 0),
#               ('B006K3V5LY', 0),
#               ('B009F3HQ14', 0)],
#              'AIE6PS00ZD2NL': [('B00099XK6I', 0),
#               ('4639725043', 0),
#               ('B00136MKEO', 0),
#               ('B00886E4K0', 0)],
#              'A19XLYBG7REBLS': [('4639725043', 0),
#               ('B000GG1S5O', 0),
#               ('B000HLCKC8', 0),
#               ('B000JSSNUC', 0),
#               ('B001VIEZLK', 0),
#               ('B000GW257S', 0),
#               ('B00NLSCUPG', 0)],
#              'A2GUE1T9LNWZ0T': [('B00006BN4U', 0),
#               ('B001EPQVFS', 0),
#               ('4639725043', 0),
#               ('B000FIWIWU', 0),
#               ('B00JI498GG', 0)],
#              'ALOGZDSPWZI72': [('B00016LZT8', 0),
#               ('B002B1HGDU', 0),
#               ('B003T0668I', 0),
#               ('B0044R3DNG', 0),
#               ('B00AD8T5UA', 0),
#               ('B001EQ56NA', 0),
#               ('B000LKXG64', 0),
#               ('B0027Z5J6G', 0),
#               ('B0046HEPRM', 0),
#               ('B0034TY0A0', 0),
#               ('4639725043', 0),
#               ('B00136MKEO', 0),
#               ('B001VNGKTA', 0),
#               ('B00O49FE8G', 0),
#               ('B001EQ4L18', 0),
#               ('B002YGY536', 0),
#               ('B000LQTTVY', 0),
#               ('B001VNO1NM', 0),
#               ('B004YPXI2O', 0),
#               ('B001VNO2HC', 0),
#               ('B00G6R3YKE', 0),
#               ('B000PWWQP0', 0),
#               ('B0001M116Y', 0),
#               ('B0078DP4IK', 0),
#               ('B007IK5QZO', 0),
#               ('B001EQ4Z96', 0),
#               ('B00IFHDLDI', 0),
#               ('B001FOPQL8', 0),
#               ('B00UU7ZSQ4', 0),
#               ('B006P90F2I', 0),
#               ('B00X1LJZUG', 0),
#               ('B0001M0Z7A', 0),
#               ('B001IZM91Y', 0),
#               ('B00J91V3GG', 0),
#               ('B000EEWZG4', 0),
#               ('B001A1VII6', 0),
#               ('B0093DB9QO', 0),
#               ('B00D8TZ5N2', 0),
#               ('B00HVJI7KI', 0),
#               ('B010NBE6HI', 0),
#               ('B001F7E95O', 0),
#               ('B000HDJXLW', 0),
#               ('B000M56BS8', 0),
#               ('B0078EZQE6', 0),
#               ('B001O4EKJI', 0),
#               ('B0027EOTKO', 0),
#               ('B005CULITU', 0),
#               ('B00ELPSOXU', 0),
#               ('B00MS95UEC', 0),
#               ('B0000EYK3E', 0),
#               ('B000LKTZSM', 0),
#               ('B000PKYVQ4', 0),
#               ('B000I4MQLE', 0),
#               ('B000KNB0OW', 0),
#               ('B00TGE5U0G', 0),
#               ('B00R2I2DH6', 0),
#               ('B0049TZA26', 0),
#               ('B00BFSP9G6', 0),
#               ('B00EHAXP88', 0),
#               ('B000WR2F0Y', 0),
#               ('B00014JNI0', 0),
#               ('B0019LRH50', 0),
#               ('B00AIR1NKG', 0),
#               ('B001VNP7L2', 0),
#               ('B000WGB3OY', 0),
#               ('B010ULFOWC', 0),
#               ('B005EKI2F6', 0),
#               ('B00CMQD3VS', 0),
#               ('B000V1JVCG', 0),
#               ('B001M0G1SW', 0),
#               ('B009PE3OX2', 0),
#               ('B005DDC4XK', 0),
#               ('B00G1X3XN6', 0),
#               ('B004HK46C2', 0),
#               ('B005JWMMUK', 0),
#               ('B00VTR18Q8', 0),
#               ('B01E6OKVY0', 0),
#               ('B003GQ0W2Q', 0),
#               ('B001BDBODC', 0),
#               ('B00RBSKOW8', 0),
#               ('B0198RNQ3I', 0),
#               ('B000N542KQ', 0),
#               ('B000N8JVZ4', 0),
#               ('B00JOUY206', 0),
#               ('B004ZQK21W', 0)],
#              'AO15IC5EEMS8P': [('B004IRSSHI', 0),
#               ('B009PIORKC', 0),
#               ('4639725043', 0),
#               ('B000NIHZMU', 0),
#               ('B00158Q2OY', 0),
#               ('B006IT0MPA', 0),
#               ('B001VNGJPA', 0),
#               ('B0076DEU1O', 0),
#               ('B000KOWLDK', 0),
#               ('B001EQ531U', 0),
#               ('B0029JU5SM', 0),
#               ('B000SEJ6SA', 0),
#               ('B00MFBSTIC', 0),
#               ('B004CMAQGK', 0),
#               ('B000E7SYLG', 0),
#               ('B004RREF5S', 0),
#               ('B009NRG8U2', 0),
#               ('B00H6XX7FO', 0),
#               ('B000GIZAS8', 0),
#               ('B0055P0N6Q', 0),
#               ('B00GIS0VES', 0),
#               ('B00099XK6I', 0),
#               ('B001CTO0YA', 0),
#               ('B001DC9SY8', 0),
#               ('B0029JZOU6', 0),
#               ('B00JWZS6N2', 0),
#               ('B0001UXQ9Q', 0),
#               ('B004MSILB6', 259200),
#               ('B006OD5ISG', 0),
#               ('B00AX0CYWE', 0),
#               ('B00FN6EC6Y', 0),
#               ('B010ZFW8AO', 0),
#               ('B000REI2X6', 0),
#               ('B006K3QOJ2', 0),
#               ('B007IAYX4E', 0),
#               ('B004CMDUMC', 0),
#               ('B00R61JSZ4', 0),
#               ('B00URV5RQE', 0)],
#              'A1D0F8HAZ66ZPY': [('B00542YXFW', 23846400),
#               ('B00AQFGL4S', 0),
#               ('4639725043', 0),
#               ('B00099XK6I', 0),
#               ('B0012BUOS4', 0),
#               ('B006045OH4', 0),
#               ('B004CGZGH0', 0),
#               ('B01EOWF1OY', 0),
#               ('B000X3IPQA', 0),
#               ('B004AE1FHY', 0)],
#              'A1CT6MLYNBG3L4': [('B0094ISOMA', 0),
#               ('B00LCMBATU', 0),
#               ('B0007QMT7O', 0),
#               ('B00099XK6I', 0),
#               ('B0012OTF3Q', 0),
#               ('B00ASD2F8O', 0),
#               ('4639725043', 0),
#               ('B0049TZA26', 0),
#               ('B002DYJ214', 0),
#               ('B01FWTV12E', 0),
#               ('B00N0H1JYG', 0),
#               ('B016JZ9OM4', 0),
#               ('B00542YXFW', 0),
#               ('B00IOP03SW', 0),
#               ('B01869K0QK', 0),
#               ('B00286KM2A', 0),
#               ('B001AY904C', 0),
#               ('B003M62ZS4', 0),
#               ('B0029JI818', 0),
#               ('B00EYFKNL8', 0),
#               ('B00N0JHZ5G', 0),
#               ('B00GY5WHTM', 0),
#               ('B00IVT3LVM', 0),
#               ('B00WL6R8CY', 0),
#               ('B01DWEZB5E', 0),
#               ('B001F35WSQ', 0),
#               ('B016J3N0TY', 0),
#               ('B00EDHW7K2', 0),
#               ('B002TY41QO', 0),
#               ('B00F2T3ES4', 0),
#               ('B007HN5KNA', 0),
#               ('B00HIP604A', 0),
#               ('B013E9PISW', 0),
#               ('B000L3TYF8', 0),
#               ('B00JVZZVA4', 0),
#               ('B0085IFB62', 0),
#               ('B00JGD3YUU', 0),
#               ('B000NIHZMU', 0),
#               ('B01CDBBB92', 0)],
#              'A1T65DGV69QI8L': [('B000FZRYPO', 0),
#               ('B00021VGPU', 0),
#               ('B00600FL4E', 0),
#               ('B000JSQK70', 0),
#               ('4639725043', 0),
#               ('B000F3S6L2', 0)],
#              'A1WOMXOEX90ARI': [('B000H7ELTW', 3628800),
#               ('B001GVIS7Y', 0),
#               ('B000FKL0D6', 0),
#               ('B000FKL0EU', 835200.0),
#               ('B000FKQD42', 0),
#               ('B001GVIS4M', 0),
#               ('B001E5E3JY', 0),
#               ('B000F9XBIE', 0),
#               ('B002FBUY0I', 0),
#               ('B000F9XBGQ', 0),
#               ('B002FBY3GE', 0),
#               ('B00542YXFW', 0),
#               ('B000EGZ9AG', 0),
#               ('B00099XNA6', 0),
#               ('B000FZYMJK', 0),
#               ('B001EO7GR6', 0),
#               ('B000KNB0OW', 0),
#               ('B000E7UJJ6', 0),
#               ('B000LKVSDM', 0),
#               ('B000E1FZCI', 0),
#               ('B001E5DYEO', 0),
#               ('B001EQ5JJQ', 0),
#               ('B001EQ5JLE', 0),
#               ('B001E5DXY0', 0),
#               ('B000E7WM14', 0),
#               ('B000GZSDZI', 0),
#               ('B000UXVJ02', 0),
#               ('B002HFPW6I', 0),
#               ('B002FBY3YG', 0),
#               ('B000SRMB16', 0),
#               ('B0019MYXXI', 0),
#               ('B0019MYYFA', 0),
#               ('B000E7WM0U', 0),
#               ('B00JSVKBQU', 0),
#               ('B000UY0JHU', 0),
#               ('B005T05FNI', 0),
#               ('B00992RFZS', 0),
#               ('B001E5E3NK', 0),
#               ('B005CJDI76', 0),
#               ('B00C3XU67Y', 0),
#               ('B003RWVFEI', 0),
#               ('4639725043', 0),
#               ('B00B93M30M', 0),
#               ('B00D9RRZ3Q', 0)],
#              'A12FEHYJOJZZRY': [('B004VLVBSY', 0),
#               ('4639725043', 0),
#               ('B001LQWO60', 0),
#               ('B000F5429A', 0),
#               ('B008TJR9JE', 0),
#               ('B00DUQNFV2', 0),
#               ('B00QGWM5HC', 0),
#               ('B001ZGD7JY', 0),
#               ('B00JFLKD48', 0),
#               ('B00NLQUFVE', 0),
#               ('B000B6MWF4', 0),
#               ('B000VDR6O4', 0),
#               ('B0014E847C', 0),
#               ('B001PQOAOA', 0),
#               ('B00AZLWTE4', 0),
#               ('B00CI6A58G', 0),
#               ('B0019O1FWS', 0),
#               ('B001EO5X4O', 0),
#               ('B001EO6BCC', 0),
#               ('B0018JHJ7O', 0),
#               ('B0076DEU1O', 0),
#               ('B001G0MG28', 0),
#               ('B00TGOEYUI', 0),
#               ('B00NHAEEIY', 0),
#               ('B006K3V5LY', 0),
#               ('B0062VQEQA', 0),
#               ('B00NHXKKIY', 0),
#               ('B01BCBX05C', 0),
#               ('B000JSQDK4', 0),
#               ('B01ACSONA2', 0),
#               ('B01AWWGE7I', 0)],
#              'A946D9M4OF57S': [('B000EM6PC6', 0),
#               ('B000QF7KIO', 0),
#               ('4639725043', 0),
#               ('B00I4W2VX0', 0),
#               ('B014GLC2LS', 0)],
#              'A2NE7D8GC41UCL': [('B001VIIXXQ', 0),
#               ('4639725043', 0),
#               ('B00C1ZQFXI', 0),
#               ('B00099XK6I', 0),
#               ('B0007QMT7O', 0),
#               ('B000F4DK9Y', 0)],
#              'A2TURHWPQ343WP': [('B000ISZ310', 0),
#               ('4639725043', 0),
#               ('B005IR6E5A', 0),
#               ('B0015Z20RU', 0),
#               ('B004VRKZT4', 0),
#               ('B00313TXTC', 0),
#               ('B00712N6II', 0),
#               ('B006O0N0WA', 0),
#               ('B00VKKJRS0', 0),
#               ('B0117QSD8G', 0),
#               ('B0079OX7H8', 0),
#               ('B01CDBJUB8', 0),
#               ('B004NF5E86', 0)],
#              'AADZHUJW0KSDC': [('B001BDDHF0', 0),
#               ('B000E63LAQ', 0),
#               ('B000WR2F0Y', 0),
#               ('B0012BQJ56', 0),
#               ('B001VNGNLU', 0),
#               ('B004743MIC', 0),
#               ('B0048IDH2S', 0),
#               ('B005DU2ROY', 0),
#               ('B00AVOGC6G', 0),
#               ('4639725043', 0),
#               ('B000EDI1O0', 0),
#               ('B000EM6PC6', 0),
#               ('B000EVMNNC', 0),
#               ('B000EVMNMI', 16070400),
#               ('B000F4DK9Y', 0),
#               ('B000FIAWVE', 0),
#               ('B000H153AE', 0),
#               ('B000HTJPRI', 0),
#               ('B000OQ4A3S', 0),
#               ('B000WJNX3A', 0),
#               ('B0014S83YC', 0),
#               ('B001EO60O6', 0),
#               ('B001SAX0EE', 0),
#               ('B001VNGJ5K', 0),
#               ('B001VNGJX2', 0),
#               ('B001VNGMMK', 0),
#               ('B001VNGOGY', 0),
#               ('B001VNGKNQ', 0),
#               ('B001VNED0I', 0),
#               ('B001VNKVPE', 0),
#               ('B001VNGOF0', 0),
#               ('B003SKR2FA', 0),
#               ('B003ZUQ984', 0),
#               ('B0045GX66A', 0),
#               ('B00542YXFW', 518400.0),
#               ('B00A2PSAOG', 0),
#               ('B00BSD9C5M', 0),
#               ('B00KRFMKAG', 0),
#               ('B000EDM7CM', 0),
#               ('B0009TN7F2', 0),
#               ('B006P9XFIO', 0),
#               ('B00ISSTOR6', 0),
#               ('B000NMCEJK', 0),
#               ('B001DC9SY8', 0),
#               ('B001E52U76', 0),
#               ('B001FA1DUA', 0),
#               ('B001FA1KRG', 0),
#               ('B002WWNLB4', 1036800),
#               ('B0043CVIWA', 0),
#               ('B005U4RFUY', 0),
#               ('B0067R3Q9M', 0),
#               ('B006OCVPPC', 0),
#               ('B000E1DS7C', 0),
#               ('B000EVPAXC', 0),
#               ('B000IXRG8S', 0),
#               ('B00BBR1G9U', 0),
#               ('B004M15QR0', 0),
#               ('B00C9I8OT0', 0),
#               ('B0014ET0OI', 0),
#               ('B006P9XF9S', 0),
#               ('B006P9XEW6', 0),
#               ('B00CPBS2E8', 0),
#               ('B00G9TR3DI', 0),
#               ('B00LE9UDNA', 0)],
#              'AWTUY65AU8UYK': [('4639725043', 0),
#               ('B000F9XBF2', 0),
#               ('B004LL5O46', 0),
#               ('B0041MDHQM', 0),
#               ('B0028PQ9BE', 0),
#               ('B001D0IZBM', 0),
#               ('B00374XTQI', 0),
#               ('B002EYZM4O', 0),
#               ('B001EQ54K0', 0)],
#              'A2FLH5F9I7LSNY': [('4639725043', 0),
#               ('B001EQ5SFG', 0),
#               ('B007FCVSXY', 0),
#               ('B009YQAUVK', 0),
#               ('B00C1LXBFC', 0),
#               ('B001GVIRYS', 0)],
#              'A3CP3OFGIU8WZQ': [('B00F5KMG0C', 0),
#               ('B00BBGODPU', 0),
#               ('B01AO38MKW', 0),
#               ('5463213682', 0),
#               ('B00JPJRQ7W', 0)],
#              'A2R6A6CZSQYNO2': [('B008P2FSKC', 0),
#               ('B00BPX4OPS', 0),
#               ('B00BUKL666', 0),
#               ('B00D3M2QP4', 0),
#               ('B008QMX2SG', 0),
#               ('B00R7PWK7W', 0),
#               ('B00W8AZPWI', 0),
#               ('B00K5YJ9YO', 0),
#               ('5463213682', 0),
#               ('B00EV17GPG', 0),
#               ('B00QL9EYM4', 0)],
#              'A3AP2B37EKUT1X': [('5463213682', 42940800),
#               ('B00DD7V2GS', 0),
#               ('B00017LF24', 0),
#               ('B00BBGODPU', 0),
#               ('B00DZ0NLLW', 0),
#               ('B00M48Z5T2', 0),
#               ('B013HAD63M', 0),
#               ('B00W1YWJBG', 0)],
#              'A2AWW9G5X8DJ6G': [('B00701PPGG', 0),
#               ('B00EKLPLU4', 0),
#               ('B000WR4SGI', 0),
#               ('B00U6UFR98', 0),
#               ('5463213682', 0)],
#              'A3KDQ6A29REK5K': [('B001EPV3LK', 0),
#               ('B004ZG4DLM', 0),
#               ('B002SWB73C', 0),
#               ('B000PIMWGM', 0),
#               ('B003ZPFOCQ', 0),
#               ('B00D1DOXOW', 0),
#               ('B00NUW6GHG', 0),
#               ('5463213682', 0)],
#              'A1KGNAFK85SNID': [('B00LKUHCX2', 0),
#               ('5463213682', 0),
#               ('B003CY45VG', 0),
#               ('B004EDBVCU', 0),
#               ('B004RYX8UO', 0),
#               ('B004UC7CMS', 0),
#               ('B005K4Q1T0', 0),
#               ('B005K4Q1YA', 0),
#               ('B00BBGODPU', 0),
#               ('B00E6FF7HG', 0),
#               ('B00K8APSMC', 0),
#               ('B00LKUFKBS', 0),
#               ('B00AULHB2Y', 0)],
#              'A2HOI7EYSMPRX9': [('B005MQKIXG', 0),
#               ('5463213682', 0),
#               ('B00BBGODPU', 604800),
#               ('B006RNRK3E', 0),
#               ('B003VXFK44', 0),
#               ('B004LU156S', 0),
#               ('B00MFNA1MC', 0)],
#              'A1PSBOJAE3L7KZ': [('B00BBGODPU', 2894400.0),
#               ('5463213682', 0),
#               ('B003V5HEXC', 0),
#               ('B003V5JHV4', 0),
#               ('B0044I7W3C', 0),
#               ('B00N9UH1DM', 0)],
#              'A2ANBEX40KLY4O': [('9742356831', 0),
#               ('B000EICJWA', 0),
#               ('B000EI2LLO', 0),
#               ('B002GWHA62', 0),
#               ('B004ZELKZG', 0),
#               ('B005G8T32M', 0)],
#              'A12FQR26O65H4M': [('9742356831', 0),
#               ('B000EI2LLO', 0),
#               ('B000JZHE1O', 0),
#               ('B016AU0ITG', 0),
#               ('B000LLK9KE', 0)],
#              'A1U32SY2BN1I4T': [('B0001M11CS', 0),
#               ('B000WR2OFK', 0),
#               ('B000WR4SGI', 0),
#               ('B001VNGO7S', 0),
#               ('B001VNP7L2', 0),
#               ('B00AJRKQDU', 0),
#               ('B001VNECGI', 0),
#               ('B00K82ZL9A', 0),
#               ('B00IZI8OC0', 0),
#               ('9742356831', 0),
#               ('B0009F3QKW', 0),
#               ('B000LRFVHE', 0),
#               ('B0014DPIPO', 0),
#               ('B0019GVBTS', 0),
#               ('B00KPX1W4U', 0),
#               ('B018CCLARE', 0),
#               ('B01GL6PRTK', 0),
#               ('B000JMDHCC', 0),
#               ('B000JSOBSU', 0),
#               ('B001E5DX4A', 0),
#               ('B001E5E3S0', 0),
#               ('B001SAY1FG', 0),
#               ('B0095FWPZE', 0),
#               ('B00FA63QA0', 0),
#               ('B00014G9XW', 0)],
#              'A2ULESH6GADUEW': [('B00B24H1NM', 0),
#               ('B00F80R95Q', 0),
#               ('B00BRFJS6E', 0),
#               ('B00LYD9KNU', 0),
#               ('9742356831', 0)],
#              'A1TI6UAU422P4Y': [('B019LQISSY', 0),
#               ('B000168QTU', 0),
#               ('B0055IRNAC', 0),
#               ('B006A4MO68', 0),
#               ('B015TNWQ5O', 0),
#               ('B015WWQAKY', 0),
#               ('9742356831', 0),
#               ('B003E1J6DY', 0),
#               ('B004AOFZRA', 0),
#               ('B010TTZVEG', 0)],
#              'A3VG446SHJH37O': [('B000LKZ78E', 0),
#               ('B001P22K5U', 0),
#               ('B00856TSCC', 0),
#               ('B019HUR0NS', 0),
#               ('9742356831', 0),
#               ('B00PKRTNF6', 0)],
#              'A88Q6B9ENKMFV': [('B008A1DW2E', 0),
#               ('B005WDVUIG', 0),
#               ('9742356831', 0),
#               ('B0197ALU34', 0),
#               ('B002NM1UYS', 0)],
#              'AR8UD52ASM42W': [('B006E0RJ0O', 0),
#               ('B01H37XMJ8', 0),
#               ('B01EUO85B2', 0),
#               ('B004HK46C2', 0),
#               ('B00VTR18Q8', 0),
#               ('9742356831', 0),
#               ('B003E1J6DY', 0),
#               ('B007ZZSOH4', 0),
#               ('B00NVECUV4', 0)],
#              'A16Q398S571Y58': [('9742356831', 0),
#               ('B000FBM54S', 0),
#               ('B0001M0Z6Q', 0),
#               ('B007JAA6N0', 0),
#               ('B010LA1S68', 0)],
#              'A3805CJX68OK7N': [('B000UWE0AO', 0),
#               ('B0051WBQ00', 0),
#               ('B00IBNZAEE', 0),
#               ('B00ZB13JHO', 0),
#               ('B005HB19KW', 0),
#               ('B00BUKL666', 0),
#               ('B00D3M2QP4', 0),
#               ('B008QMX2SG', 0),
#               ('B00R7PWK7W', 0),
#               ('B000E123IC', 0),
#               ('B01FKV4CBG', 0),
#               ('B002RBRY0Y', 0),
#               ('B00LAQ4Z1I', 0),
#               ('B00NB7CAUW', 0),
#               ('9742356831', 0)],
#              'A257RYQUA7GLAE': [('B0045IO2VQ', 0),
#               ('B00U7WVZYG', 0),
#               ('B000E3ZFDK', 0),
#               ('9742356831', 0),
#               ('B00K2RY8GI', 0)],
#              'A3OKJEXRS7RFLK': [('B00542YXFW', 0),
#               ('B000Z9ASSK', 0),
#               ('9742356831', 0),
#               ('B00269VK20', 0)],
#              'A17FA8KTT1W2EL': [('B000E63LQU', 0),
#               ('B001OHX1HM', 0),
#               ('B0055T5VB4', 0),
#               ('B00C0TEIYI', 0),
#               ('B00ENMZ6IW', 0),
#               ('B000HDJZWO', 0),
#               ('B009324C0U', 0),
#               ('B00AQFGL4S', 0),
#               ('B00CLLV2D0', 0),
#               ('9742356831', 0),
#               ('B000EIE7GQ', 0),
#               ('B000EI2LLO', 0)],
#              'A3OP4TYQKVX1MH': [('9742356831', 0),
#               ('B000EICJWA', 0),
#               ('B000EIE7GQ', 0),
#               ('B000YCNFCY', 0),
#               ('B000EICISA', 0)],
#              'AUBNAL9E19PKG': [('B008CFOACO', 0),
#               ('B00FJ4MLMW', 0),
#               ('9742356831', 0),
#               ('B000EICISA', 0),
#               ('B00027EKKW', 0),
#               ('B0013P3KC6', 0),
#               ('B000EI2LLO', 0)],
#              'A2A1QUMBKLPAOQ': [('B001AY8VV0', 0),
#               ('B003XB3NNE', 0),
#               ('B007GPARA0', 0),
#               ('B01DPYRCTE', 0),
#               ('B00O647RR0', 0),
#               ('B0149H9TTM', 0),
#               ('9742356831', 0),
#               ('B0067SECAS', 0),
#               ('B006DI87GM', 0),
#               ('B015WU3X5Q', 0),
#               ('B00IMS0CZA', 0)],
#              'A3R6UAR8X4OTMI': [('9742356831', 0),
#               ('B000EICJWA', 0),
#               ('B000EICISA', 0),
#               ('B000EI2LLO', 0),
#               ('B008E0XYCE', 0),
#               ('B00JKMTGBS', 0),
#               ('B00SEIBJQE', 0),
#               ('B014QYUMU8', 0),
#               ('B01D4VO58E', 0),
#               ('B01DCUTJJM', 0)],
#              'A35Q0JH999NPN0': [('B000BD0SDU', 54518400.0),
#               ('B005HGOIQ4', 0),
#               ('B00027EKKW', 0),
#               ('B000A7B5UM', 0),
#               ('B000EDK5LM', 0),
#               ('B000LKZ84C', 0),
#               ('B0013P3KC6', 0),
#               ('B0014A05FK', 0),
#               ('B0014ROZXG', 0),
#               ('B0014RK2F6', 0),
#               ('B009E7YBEQ', 0),
#               ('B0000W0GQQ', 0),
#               ('B000LRKO1C', 0),
#               ('B000NB5AUG', 0),
#               ('B003XKF6CQ', 0),
#               ('B004CGC86C', 0),
#               ('B004CSZRVI', 0),
#               ('B004CGE4FU', 0),
#               ('B000S6CCJ8', 0),
#               ('B00B40L32O', 0),
#               ('B0045DISDO', 0),
#               ('B008VQ5A0K', 0),
#               ('B00CMQE1QE', 0),
#               ('B006IMBHVU', 0),
#               ('B00CMQE1NW', 0),
#               ('B000CR1ELU', 0),
#               ('B00ZDO82VM', 0),
#               ('B000FFIL60', 0),
#               ('B00BUKL666', 0),
#               ('B00D3M2QP4', 0),
#               ('B008QMX2SG', 0),
#               ('B00KSN9TME', 0),
#               ('B00MGXP5N6', 0),
#               ('9742356831', 0),
#               ('B00WT4WXTQ', 0)],
#              'AWYQR5G9X8OLC': [('B001SB1SEM', 0),
#               ('B0066NZFKA', 3801600),
#               ('B007SM6NWC', 0),
#               ('B00ARABK20', 0),
#               ('9742356831', 0),
#               ('B000EICJWA', 0),
#               ('B004AOFZPW', 0)],
#              'A4PW79CXS4J2O': [('B001E5E2FE', 0),
#               ('B002DVNM7W', 0),
#               ('9742356831', 0),
#               ('B000X1T24G', 0),
#               ('B00QXR8E1Q', 0)],
#              'A11HDGAXIZ12QU': [('B000F4DK9Y', 45446400),
#               ('B002GWHBGQ', 0),
#               ('B000JMFEJG', 0),
#               ('B019AUVQOO', 0),
#               ('9742356831', 0),
#               ('B004QZKZ0A', 0)],
#              'A129WOVAGC38GY': [('9742356831', 0),
#               ('B00473PVVO', 0),
#               ('B000EICJWA', 0),
#               ('B0052OP3EC', 0),
#               ('B00NIO5YZ6', 0)],
#              'A3NMBW09DL5VUX': [('B001O1Q0NA', 0),
#               ('B00XANCAQ6', 0),
#               ('9742356831', 0),
#               ('B000EI2LLO', 0),
#               ('B00O3I9M4K', 0),
#               ('B01H6IQING', 0),
#               ('B000EICJWA', 0),
#               ('B007RAM3VK', 0)],
#              'A3VWC90VYNFTBM': [('B00I7FCIJ6', 0),
#               ('B00A6GWRK4', 0),
#               ('B00ERWVI8A', 0),
#               ('9742356831', 0),
#               ('B00FMOZOMI', 0)],
#              'A1BJVYTBOS2AGM': [('B005U4RFUY', 0),
#               ('B0003295CE', 0),
#               ('B0006B4IHO', 0),
#               ('B005OC0YA0', 0),
#               ('B006O4PY2K', 0),
#               ('B008Y2QZ46', 0),
#               ('B00AOMO9RO', 0),
#               ('B0014CTT6Y', 0),
#               ('B004IJ85VK', 0),
#               ('B00N4Z5XQY', 0),
#               ('B00NLQUFVE', 0),
#               ('B003ZWK1IQ', 0),
#               ('B00017Y986', 0),
#               ('B0019K980I', 0),
#               ('B001C5KY58', 0),
#               ('B001HTR1ZU', 36201600),
#               ('B0025UC2KE', 0),
#               ('B002WWRLP6', 0),
#               ('B003G50HPE', 0),
#               ('B004VITI0K', 0),
#               ('B0050ILG4Q', 0),
#               ('B0058AMYTC', 36201600),
#               ('B005ECOBRM', 0),
#               ('B00KO1DQGK', 0),
#               ('B0014H17LO', 0),
#               ('B00GQE3LYG', 0),
#               ('B001YJ9IAO', 0),
#               ('B000LQNK6E', 0),
#               ('B000OUX2QA', 0),
#               ('B002CIP40E', 0),
#               ('B004YKAX2M', 0),
#               ('B009HHNUUE', 0),
#               ('B00AHASEGA', 0),
#               ('B00B1OWWXC', 0),
#               ('B0009RVFJE', 0),
#               ('B003XV1T6C', 0),
#               ('B004YGQK5K', 0),
#               ('B0054TWQ3Q', 0),
#               ('B006NI9PKO', 0),
#               ('B00HF7VRFS', 0),
#               ('B0014CZ08K', 0),
#               ('B0006G1KAM', 0),
#               ('B000FVMQJC', 0),
#               ('B0012OTHB6', 0),
#               ('B001M09BHU', 0),
#               ('B002YFUOEG', 0),
#               ('B006U0QVMK', 0),
#               ('B008MMJTKU', 0),
#               ('B00BO0KZ0A', 0),
#               ('B00OXAXUIM', 0),
#               ('B001E1PR4S', 0),
#               ('B005HGJ8IW', 0),
#               ('B007JAA6N0', 0),
#               ('B00JSUCSJE', 0),
#               ('B00BLTKUJ0', 0),
#               ('B0178IOBVU', 0),
#               ('B0001M0Z6Q', 0),
#               ('B001PB30AK', 0),
#               ('B0044MNYIK', 0),
#               ('B007ZN4EZ2', 0),
#               ('B00HQDVRU6', 0),
#               ('B003RQI13C', 0),
#               ('B00QH73L9C', 0),
#               ('B00ZAJHC3E', 0),
#               ('B00JVTFQL4', 0),
#               ('B0014DXL44', 0),
#               ('B0019LRH50', 0),
#               ('B001EPQOM8', 0),
#               ('B0028LGNSM', 0),
#               ('B00A95TKQ6', 0),
#               ('B00KB55F22', 0),
#               ('B00MWDFFT4', 0),
#               ('B00WNC0VR0', 0),
#               ('B013IG9KVW', 0),
#               ('B01974FVDU', 0),
#               ('B01AE8SOTQ', 0),
#               ('B00018XFFI', 0),
#               ('B000AY9VCE', 0),
#               ('B000EQT77M', 0),
#               ('B000JMAVQC', 0),
#               ('B000R923TU', 0),
#               ('B004U771H4', 0),
#               ('B004XTDNF8', 0),
#               ('B008SYVF4K', 0),
#               ('B00BMJR13M', 0),
#               ('B00DZ41QHO', 0),
#               ('B00E6RRHK4', 0),
#               ('B00L5PNECU', 0),
#               ('B00N7JYQLA', 0),
#               ('B00XTGVRLI', 0),
#               ('B01C0VB3C0', 0),
#               ('B00835U536', 0),
#               ('B00835U54A', 0),
#               ('B00019OV8M', 0),
#               ('B000XBCBW6', 0),
#               ('B002WQ8UC0', 0),
#               ('B006RIYBD6', 0),
#               ('B003LJUNH2', 0),
#               ('B005MJTFFA', 0),
#               ('B00KC6C8M0', 0),
#               ('B00MX34X5A', 0),
#               ('B0134ETWMU', 0),
#               ('B01HHH9YRS', 0),
#               ('9742356831', 0),
#               ('B000EICISA', 0),
#               ('B00112UBOG', 0),
#               ('B0044M10OK', 0),
#               ('B000EI2LLO', 0),
#               ('B00AC7QSS4', 0),
#               ('B00OJD0KIG', 0),
#               ('B0001990A6', 0),
#               ('B006E5E8O4', 0),
#               ('B007VDNW2W', 0),
#               ('B01BL0BW1S', 0),
#               ('B01CU5YVOI', 0)],
#              'A31GYNW4UGVZNK': [('9742356831', 0),
#               ('B000DZE0XK', 0),
#               ('B000EICJWA', 0),
#               ('B000EIE7GQ', 0),
#               ('B000QU3JM0', 0),
#               ('B000XTW9GG', 0),
#               ('B001ET5Y0M', 0),
#               ('B000EI2LLO', 0),
#               ('B00LI3O93W', 0),
#               ('B00MXXUXPE', 0),
#               ('B00U9WPTFK', 0)],
#              'A11T8734N6X8R0': [('B000GFYRI0', 0),
#               ('B000SWTKV0', 0),
#               ('B001ROJ3FQ', 0),
#               ('9742356831', 0),
#               ('B0186XTAUI', 0)],
#              'A3QBYM820VKKVK': [('9742356831', 0),
#               ('B000EICJWA', 0),
#               ('B000EIE7GQ', 0),
#               ('B000EICISA', 0),
#               ('B000V8BJUQ', 0),
#               ('B0014E847C', 0),
#               ('B001PQOAOA', 0),
#               ('B000NMI6LU', 0)],
#              'AQET1BK47B2HV': [('B003ULFXWQ', 0),
#               ('B00COUR0NE', 0),
#               ('B00ICPZ75I', 0),
#               ('B0001LO3FG', 0),
#               ('B000F4DKAI', 0),
#               ('B001FVPAZ8', 0),
#               ('B001KUWFHA', 0),
#               ('B004AHIBB4', 0),
#               ('B00LXIKRC4', 0),
#               ('B0187W2PAA', 0),
#               ('B000EI2LLO', 0),
#               ('B016VJ8XQQ', 0),
#               ('B000NO943C', 0),
#               ('9742356831', 0),
#               ('B00016LAFM', 0),
#               ('B00F70KI5K', 0),
#               ('B00E18SMCA', 0)],
#              'A36AKNBXEYHNNS': [('9742356831', 0),
#               ('B001NI7OGG', 0),
#               ('B00IBNAW24', 0),
#               ('B00PSZKXRW', 0),
#               ('B00PT0QC8U', 0)],
#              'A3LXB49N4XLHUC': [('9742356831', 0),
#               ('B00276H5GW', 0),
#               ('B003T0668I', 0),
#               ('B00C8XYYNG', 0),
#               ('B00HCNCQ2S', 0),
#               ('B006684PPQ', 0),
#               ('B00CHTSPKY', 0),
#               ('B00338DPV2', 0),
#               ('B00BTCR9P2', 0),
#               ('B001UOW7D8', 0),
#               ('B001YJ9JBW', 0),
#               ('B0045DMLXM', 0),
#               ('B004NRLAVY', 0),
#               ('B007BJ0UGC', 0),
#               ('B00C2POT3K', 0),
#               ('B00CSRMYDE', 0),
#               ('B00M8M2SKS', 0),
#               ('B00OCV3QRW', 0),
#               ('B003WT71MG', 0),
#               ('B006M4PQWU', 0),
#               ('B01BFRVXHA', 0),
#               ('B007IAYX4E', 0)],
#              'A2S3PZG5FGY25I': [('B0198W203U', 0),
#               ('9742356831', 0),
#               ('B000EICISA', 0),
#               ('B003PPAS9K', 0),
#               ('B005CK1GQU', 0),
#               ('B001E5DX4A', 0),
#               ('B00EVQ6E3Q', 0)],
#              'A1DPL1U5607IZY': [('B001SB1SEM', 0),
#               ('B00MEUUBZI', 0),
#               ('B0001DMTPU', 0),
#               ('B000F865ZQ', 0),
#               ('B00269PM6K', 0),
#               ('B005WXMPMQ', 0),
#               ('B000EI2LLO', 0),
#               ('B00J5S4SEM', 0),
#               ('B00PNMFS20', 0),
#               ('9742356831', 0)],
#              'A3QTEUV6NFD5QH': [('B000EM6PS0', 10713600),
#               ('B001HTJ2BQ', 0),
#               ('B00DDG90AY', 0),
#               ('B00E0WB292', 0),
#               ('B004391DK0', 0),
#               ('9742356831', 0),
#               ('B007JINB0W', 0),
#               ('B01B5EF0OK', 0)],
#              'A2JLS05I6QXDEL': [('B000VVWUMY', 0),
#               ('B00028MOQS', 0),
#               ('9742356831', 0),
#               ('B00BGVK3J0', 0),
#               ('B01GO3HI8S', 0)],
#              'A18FCDYN7D4QHW': [('B007D7OUE0', 0),
#               ('B00F0RDRW6', 0),
#               ('B00Y8HZS1W', 0),
#               ('B0045DS4M4', 0),
#               ('9742356831', 0),
#               ('B000EICJWA', 0),
#               ('B000GZSDZI', 0),
#               ('B000LKXADS', 0),
#               ('B000EI2LLO', 0),
#               ('B007FMLMFS', 0),
#               ('B00AJRKHZC', 0),
#               ('B00VQ8FIOI', 0)],
#              'A1R0Z1BJGWRH8E': [('B001EO5WZ4', 0),
#               ('B0004MTM9O', 0),
#               ('B0004N0IBO', 0),
#               ('B004TSYEGA', 0),
#               ('B00D3RKTZS', 0),
#               ('B00D4LVU0Q', 0),
#               ('9742356831', 0),
#               ('B001F35WU4', 0),
#               ('B00U7794QW', 0),
#               ('B00FRTS2CW', 0)],
#              'ANTWFVZZKSBSF': [('B0051C0EZI', 0),
#               ('B0058MKAAU', 0),
#               ('B00HI6ZH70', 0),
#               ('B004M1R4LG', 0),
#               ('B004Z4PKP2', 0),
#               ('B003V0K7PE', 0),
#               ('B000FYVKPU', 0),
#               ('B001RBMADG', 0),
#               ('B004W3H73E', 0),
#               ('B00BHFED2I', 0),
#               ('B00778B90S', 0),
#               ('B00A8257M6', 0),
#               ('B00ADG744Q', 0),
#               ('9742356831', 0),
#               ('B000EVMNMI', 0),
#               ('B000MIFS4S', 0),
#               ('B000N542KQ', 0),
#               ('B000O9WEY2', 0),
#               ('B000VDYPTI', 0),
#               ('B001EQ4AKU', 0),
#               ('B001NJJOCW', 0),
#               ('B00473PVVO', 0),
#               ('B004LWOJC8', 0),
#               ('B000EI2LLO', 0),
#               ('B006W5WBUO', 0),
#               ('B00C3YA8JE', 0),
#               ('B00CUINRG4', 0),
#               ('B00V1P94N2', 0),
#               ('B00V1PA6G6', 0),
#               ('B00V1P9SBU', 0),
#               ('B00XABL28K', 0),
#               ('B00ZBK44LA', 0),
#               ('B0108CNIZI', 0),
#               ('B010UPZL7Q', 0),
#               ('B011B6RG6C', 0),
#               ('B016RY7YXI', 0),
#               ('B00TFRBF12', 0),
#               ('B00VWEZW10', 0),
#               ('B001EQ5S7E', 0),
#               ('B013OY2BJG', 0),
#               ('B001BY5JH8', 0),
#               ('B008TSVXWE', 0),
#               ('B009LIVYNY', 0),
#               ('B009PIILEK', 0),
#               ('B00FL5YBIQ', 0),
#               ('B00K61RTT8', 0),
#               ('B00Y0UWXVU', 0),
#               ('B011B6RWJS', 0),
#               ('B0007R9L4M', 0),
#               ('B001HTR1ZU', 0),
#               ('B003XUJ564', 0),
#               ('B0058AMYTC', 0),
#               ('B00HQDVRU6', 0),
#               ('B0007QMT7O', 0),
#               ('B01AASTRYG', 0),
#               ('B00BFA8BF0', 0),
#               ('B00C8XYYNG', 0),
#               ('B00Y2WYAMQ', 0)],
#              'A352BSU0MFD7L7': [('B005PI0RJG', 0),
#               ('B00ABKWSTA', 0),
#               ('B0027Z5J6G', 0),
#               ('B003D331B6', 0),
#               ('B000E60TMY', 0),
#               ('B001GVIT9Q', 0),
#               ('B00WBUX2UM', 0),
#               ('B00014JNI0', 0),
#               ('B0019I2FP0', 0),
#               ('B001FVQI5Y', 0),
#               ('B001FY0GMC', 0),
#               ('B001GVIT6E', 0),
#               ('B004L3VKKG', 0),
#               ('B000LL0R8I', 0),
#               ('B00EKLPLU4', 0),
#               ('B01E5XTW24', 0),
#               ('B002VLZ81M', 0),
#               ('B00JH4HH2E', 0),
#               ('B000ETLOPW', 0),
#               ('B00117CG30', 0),
#               ('B00EHLRMOK', 0),
#               ('B00FO2BZVW', 0),
#               ('B004LKVRKM', 0),
#               ('B00FX6NXNC', 0),
#               ('B00SAX0MLQ', 0),
#               ('B0009F3PJE', 0),
#               ('B004W99BZK', 0),
#               ('B00MMNO5MC', 0),
#               ('9742356831', 0),
#               ('B000EI2LLO', 0),
#               ('B00LGW296Y', 0),
#               ('B001LO514Y', 0),
#               ('B016J3N0TY', 0),
#               ('B000MIAOYC', 0),
#               ('B000KOUKK6', 0)],
#              'A1J5SJC832IB2K': [('B000H25VVE', 0),
#               ('B002Y2SLYE', 0),
#               ('B003D331JS', 0),
#               ('B00934O46K', 0),
#               ('B000EF3FU8', 0),
#               ('B001EPQO6E', 0),
#               ('B001EPQNCO', 0),
#               ('B001EQ5OVY', 0),
#               ('B005VOOOPM', 0),
#               ('B001E55ZQO', 0),
#               ('B00UZBEIO8', 0),
#               ('B001E5E0NI', 0),
#               ('B00BV27Y4Q', 0),
#               ('9742356831', 0),
#               ('B00C7UR6YY', 0),
#               ('B004W99BZK', 0)],
#              'A216SKRFFQU4ZM': [('B0001N7RLQ', 0),
#               ('B000CR06BO', 0),
#               ('B000FEH6XU', 0),
#               ('B000EVMNMI', 0),
#               ('B002ZQ8F2M', 0),
#               ('B001UOW7D8', 0),
#               ('B0096QZ6NK', 0),
#               ('B001216DFM', 0),
#               ('B005PXEII2', 0),
#               ('B0001WOSQY', 0),
#               ('B00XK8MP2A', 0),
#               ('B001SAO8PE', 0),
#               ('B001PEWJWC', 0),
#               ('B00EKLPLU4', 0),
#               ('B000MGR3HK', 0),
#               ('B0023V2EWG', 0),
#               ('B0026NAQKS', 0),
#               ('B000V8BJVU', 0),
#               ('B003J4M8HW', 0),
#               ('B004Z306D4', 0),
#               ('B000O807YM', 0),
#               ('B00407GA6M', 0),
#               ('B007EMYD8M', 0),
#               ('B00BTJIMEC', 0),
#               ('B001GQ3E4G', 0),
#               ('B00408KDP0', 0),
#               ('B006045OH4', 0),
#               ('B00PACG9QW', 0),
#               ('B00B4HJMC0', 0),
#               ('B000ILEMAU', 0),
#               ('B00473Q9R4', 0),
#               ('B006FXKSJY', 0),
#               ('B0001JXDTA', 0),
#               ('B001EPPB9A', 0),
#               ('B0026PCGEK', 0),
#               ('B003O6CRIK', 2246400),
#               ('B00G6CLLLI', 0),
#               ('B000JMDHDG', 0),
#               ('B0099X77Y6', 0),
#               ('B004S8CMVK', 0),
#               ('B0051WBQ00', 0),
#               ('B0052XRMJ2', 0),
#               ('B00IO1YPT4', 0),
#               ('B000F08KCU', 0),
#               ('B00II0XUF6', 0),
#               ('B000E1FXQ6', 0),
#               ('B001FSISXM', 0),
#               ('B000EUD6AM', 0),
#               ('B016Z3QNLU', 0),
#               ('B001KWGTWA', 0),
#               ('B00CMGRNAK', 0),
#               ('9742356831', 0),
#               ('B000EIE7GQ', 0),
#               ('B000EI2LLO', 0),
#               ('B0055E6SVG', 0),
#               ('B015EQFKPE', 0),
#               ('B00D1W8XX0', 0),
#               ('B00IFPVSIK', 0),
#               ('B00BC4IS52', 0),
#               ('B004K69OMU', 0),
#               ('B00BPYJ4ZW', 0),
#               ('B00DQUG262', 0),
#               ('B00KB1Q41M', 0),
#               ('B000SRMB16', 0),
#               ('B00GF5WILI', 0),
#               ('B002VLZ81M', 0),
#               ('B00JPJRQ7W', 0),
#               ('B00UHNIXMC', 0),
#               ('B01E7MTNFE', 0),
#               ('B00WAJ197W', 0),
#               ('B00E0WB292', 0),
#               ('B00623HKBQ', 0),
#               ('B00C44Z66I', 0),
#               ('B001PF1846', 0),
#               ('B001PQOAP4', 0),
#               ('B00269XE0Q', 0),
#               ('B002YR7A78', 0),
#               ('B000J41TB6', 0),
#               ('B001E127O6', 0),
#               ('B003V5V5J6', 0),
#               ('B0087RVIOU', 0),
#               ('B00HB6O2GO', 0),
#               ('B01A05H1DS', 0),
#               ('B00488N8KY', 0),
#               ('B00DILCU92', 0),
#               ('B01F2MKCK8', 0),
#               ('B000ED9LIU', 0),
#               ('B001M1V58M', 0),
#               ('B00DVZ2FKE', 0),
#               ('B0057FSX3Y', 0),
#               ('B01FCVTX2C', 0),
#               ('B000XBCBW6', 0),
#               ('B0044MNYIK', 0),
#               ('B005HBTNH8', 0),
#               ('B001K2KR46', 0),
#               ('B013IG9KVW', 0),
#               ('B00022DRVK', 0),
#               ('B00GZCEZ4O', 0),
#               ('B00BT7C9R0', 0),
#               ('B0000TA3SK', 0),
#               ('B00BC2CZEO', 0),
#               ('B004VITI0K', 0),
#               ('B000E1FZHS', 0),
#               ('B000U0OUP6', 0),
#               ('B00RW0MZ6S', 0),
#               ('B00XOORKRK', 0),
#               ('B001395NZ4', 0),
#               ('B001SB1SEM', 0),
#               ('B004KUV136', 0),
#               ('B00EQA93OY', 0),
#               ('B00I9DALUY', 0),
#               ('B00C90B544', 0),
#               ('B001VNKZQY', 0),
#               ('B000HDK0DC', 0),
#               ('B000X3TPHS', 0),
#               ('B00D5AZ4S0', 0),
#               ('B004HK46C2', 0),
#               ('B009GGTM30', 0),
#               ('B00K1KQBS4', 0),
#               ('B00VTR18Q8', 0),
#               ('B003WT31IY', 0),
#               ('B000E48IMO', 0),
#               ('B00CHUCBIK', 0),
#               ('B002978HHA', 0),
#               ('B000MIDVAG', 0),
#               ('B00IAE8ZQY', 0),
#               ('B00T0BUKW8', 0),
#               ('B000GZSDZI', 0),
#               ('B00G6KGXAE', 0),
#               ('B00H4ABP08', 0),
#               ('B000SAFNPE', 0),
#               ('B0197BPPIE', 0),
#               ('B017UMTZK6', 0),
#               ('B00473OM0K', 0),
#               ('B0014EQHG2', 0),
#               ('B001LFABO8', 0),
#               ('B00KY3DMRQ', 0),
#               ('B000KEJMRI', 0),
#               ('B00KPVJKAK', 0),
#               ('B00KRFLDBS', 0),
#               ('B00OAEVSTY', 0),
#               ('B01H6IQING', 0),
#               ('B017BUFAL0', 0),
#               ('B00GDMAJB4', 0),
#               ('B001NZUJ2A', 0),
#               ('B00176L6PE', 0),
#               ('B001C5Z23M', 0),
#               ('B006RIYBD6', 0),
#               ('B00DWG18SM', 0),
#               ('B00DDGQSF4', 0),
#               ('B01CNEKOWO', 0),
#               ('B01GQ5GQEG', 0),
#               ('B000CQID2Y', 0),
#               ('B004ZXZFU8', 0),
#               ('B00BOXK4RQ', 0),
#               ('B01E9HQX7S', 0),
#               ('B005IVP3CG', 0),
#               ('B00C3J9ADY', 0),
#               ('B00HVJIKZ0', 0),
#               ('B00L5RLCIG', 0),
#               ('B00D0G3GFW', 0),
# ...
#               ('B00BRKF8DG', 0),
#               ('B0009F3QKW', 0),
#               ('B003CLGE5E', 0),
#               ('B00Q7KTOC2', 0)],
#              'A1QQ1O89UDV5WB': [('B00U82TDT4', 0),
#               ('B00MOSROJG', 0),
#               ('B0000CFH7B', 0),
#               ('B00746WGV4', 0),
#               ('B017Y9HNY0', 0),
#               ('B00YU1MNV4', 0)],
#              'A35G8XLKENLP7J': [('B001MVCUYK', 0),
#               ('B00HK4AN74', 0),
#               ('B00HK59PEK', 0),
#               ('B00NEAH8EE', 0),
#               ('B0000CFH7B', 11059200),
#               ('B003KK42V0', 0),
#               ('B0043FC4GQ', 0),
#               ('B005HB19KW', 0),
#               ('B004495OP4', 0)],
#              'A2XTJ1893RH0KS': [('B00181U5A0', 0),
#               ('B0028GY9J2', 0),
#               ('B005HGNJW8', 0),
#               ('B001P22S8O', 0),
#               ('B00F1G84ME', 0),
#               ('B017GC6LXY', 0),
#               ('B0000CFH7B', 0),
#               ('B009I463JQ', 0),
#               ('B001EQ4ORY', 0),
#               ('B00032BPCM', 0),
#               ('B00KRFL5SO', 0)],
#              'A3PYGH5S6P3LHC': [('B00076TQ1G', 0),
#               ('B005TBURAI', 42508800),
#               ('B000LKVIEG', 0),
#               ('B0000CFH7B', 0),
#               ('B000G8399A', 0)],
#              'ABV65B2965DST': [('B0000CFH7B', 0),
#               ('B002ATDX7G', 0),
#               ('B00523NRVO', 0),
#               ('B00IFGPTB6', 0),
#               ('B00JSW59PW', 0),
#               ('B00PB11TIK', 0)],
#              'A2T7X252H9762R': [('B000N8N7K4', 0),
#               ('B009IJ6LAW', 0),
#               ('B0001N7RLQ', 0),
#               ('B000FEH6XU', 0),
#               ('B005G2FC50', 0),
#               ('B00I8H6MYA', 0),
#               ('B009AEFP4S', 0),
#               ('B0001LO3FG', 0),
#               ('B000F4DKAI', 0),
#               ('B00E4DGQY8', 0),
#               ('B00XA8XWGS', 0),
#               ('B0000VZ6HG', 0),
#               ('B00719WZME', 0),
#               ('B00BCL2UK4', 0),
#               ('B00FGQTO0A', 0),
#               ('B004PEKELM', 0),
#               ('B005YYFHCS', 0),
#               ('B003NC70X2', 0),
#               ('B00ZK6FXPG', 0),
#               ('B00HUC3FOE', 0),
#               ('B00CDWQ3WW', 0),
#               ('B003SBRP1K', 0),
#               ('B0000CFH7B', 0),
#               ('B00KQ1LASE', 0)],
#              'A1LAVWB1SV76JA': [('B0000CFH7B', 0),
#               ('B0018AN2T2', 0),
#               ('B002DYJ214', 0),
#               ('B003KK42V0', 0),
#               ('B004CMDUMC', 0),
#               ('B0061TXUNS', 0),
#               ('B004BPX6JW', 0),
#               ('B007C5FLMI', 0)],
#              'A16XAW90Q8O71O': [('B006OD5ISG', 0),
#               ('B0009VZP6Y', 0),
#               ('B00M8KO12I', 0),
#               ('B001EQ4CT4', 0),
#               ('B0002PHEU2', 0),
#               ('B0000CFH7B', 0),
#               ('B001F35WSQ', 0),
#               ('B001EQ4Z96', 0)],
#              'A3LORX8GMX1WCT': [('B001AO2HCO', 0),
#               ('B0069V18AU', 0),
#               ('B0000CFH7B', 0),
#               ('B0000VM9EE', 0),
#               ('B000ZEIR6U', 0),
#               ('B006XV3A5C', 0),
#               ('B007K6SSTC', 0),
#               ('B00F6ARC1E', 0),
#               ('B00KCUXRLC', 0)],
#              'A1RG9Y9RQZM507': [('B0000CFH7B', 0),
#               ('B005EGW9L8', 0),
#               ('B00D0VY8BS', 0),
#               ('B00D0VZ4RU', 0),
#               ('B00D6LXNGI', 0),
#               ('B00IFGPTB6', 0),
#               ('B00KGWYQZW', 0),
#               ('B00O3K1YJ4', 0)],
#              'AP7XI9E7W0KF7': [('B00KSK2J24', 0),
#               ('B000E1HUVC', 0),
#               ('B0000CFH7B', 0),
#               ('B005XEO112', 0),
#               ('B00KCUXRLC', 0),
#               ('B000MT22QE', 0),
#               ('B000ZEIR6U', 0),
#               ('B00UM07GZK', 0),
#               ('B000VTBFIG', 0)],
#              'A1IOTIF1PMXNH5': [('B001EQ5BUI', 0),
#               ('B0004JR8SE', 0),
#               ('B00F9WXNU8', 0),
#               ('B000O9T4FY', 0),
#               ('B003QNHT7U', 0),
#               ('B005GLXRC6', 0),
#               ('B0000CFH7B', 432000.0)],
#              'A3GU6AGSLM09IA': [('B004C9PTCE', 0),
#               ('B00M2OGS08', 0),
#               ('B0000CFH7B', 0),
#               ('B002ESMSRO', 0),
#               ('B006Y7WJM0', 0),
#               ('B00TSQSGU8', 0)],
#              'A3K91X9X2ARDOK': [('B0054TWQ3Q', 0),
#               ('B0054TWQ2C', 0),
#               ('B00KJG3M8C', 0),
#               ('B00GO6RICM', 0),
#               ('B001GVISU6', 0),
#               ('B0000CFH7B', 0),
#               ('B00NSC3BS0', 0),
#               ('B011LVDDFA', 0),
#               ('B015J5I3QS', 0),
#               ('B00U45YWSW', 0),
#               ('B01CR5OXAI', 0),
#               ('B0012HP1BI', 0),
#               ('B001DCEFSC', 0),
#               ('B00AFDB9XO', 0),
#               ('B0054TWQ36', 0)],
#              'A7PV0NAA2D1EG': [('B001XUO8AY', 0),
#               ('B0000CFH7B', 0),
#               ('B0009WUXCO', 0),
#               ('B00KGD9K6G', 0),
#               ('B0079OX8EK', 0),
#               ('B01B6WUB2W', 0)],
#              'AQNC9C1IFX2PU': [('B0055DCZCI', 0),
#               ('B00CRJDJTG', 0),
#               ('B0042YATG0', 0),
#               ('B0000CFH7B', 0),
#               ('B0000CFMU3', 0),
#               ('B000FRUNL4', 0),
#               ('B0012A8GVC', 0),
#               ('B002DYJ214', 0),
#               ('B002PNURMG', 0),
#               ('B002QJ5SM8', 0),
#               ('B004WOU1NG', 0),
#               ('B0017JVH5A', 0),
#               ('B003KK42V0', 0),
#               ('B00UQR0TAI', 0)],
#              'A47DGFXANWTY0': [('B004JRSAJS', 0),
#               ('B0043ZF2TW', 0),
#               ('B007MI2O6G', 0),
#               ('B00BUKL666', 0),
#               ('B00TBUHRRO', 0),
#               ('B0017I8URO', 0),
#               ('B0000CFH7B', 0),
#               ('B00032K7Y4', 0),
#               ('B00EZL9DSK', 0)],
#              'AIAS4YFLHJWW6': [('B001EQ55TU', 0),
#               ('B00110FINM', 0),
#               ('B00DUQNFSU', 0),
#               ('B0000CFH7B', 0),
#               ('B00AAJRPZY', 0)],
#              'A2O489VAPVIH35': [('B001F8ROTG', 0),
#               ('B001EO684I', 0),
#               ('B00851GRW6', 0),
#               ('B00H889MGK', 0),
#               ('B0000CFH7B', 0),
#               ('B00BIIOPHM', 0),
#               ('B00BJEXF4E', 0),
#               ('B00BIYAE08', 0),
#               ('B00BJFBJQE', 0),
#               ('B00FX6NXNC', 0),
#               ('B00SAX0MLQ', 0),
#               ('B000E1FZHS', 0),
#               ('B000U0OUP6', 0),
#               ('B00RW0MZ6S', 0),
#               ('B00HZ7HSTW', 0),
#               ('B00BUKL666', 0),
#               ('B00D3M2QP4', 0),
#               ('B008QMX2SG', 0),
#               ('B00KSN9TME', 0),
#               ('B00QQQQHQS', 0),
#               ('B005O8B142', 0),
#               ('B00RJM2GX6', 0),
#               ('B0093J41PE', 0),
#               ('B002VLZ81M', 0)],
#              'AL7WMBKPEZU30': [('B0000CFH7B', 864000),
#               ('B004UIWBL4', 0),
#               ('B00SC16JYK', 0),
#               ('B000Q6I9UG', 0),
#               ('B000WV0RW8', 0),
#               ('B002C08SS2', 0),
#               ('B00H5WG6IG', 0),
#               ('B00BRFJS6E', 0),
#               ('B00BOUITEE', 0),
#               ('B01BEV6RI2', 0),
#               ('B00MJ21AKG', 0)],
#              'A20GWZK550Q4WY': [('B001D4XM48', 0),
#               ('B0001N7RLQ', 0),
#               ('B004N8LMFM', 0),
#               ('B0000CFH7B', 0),
#               ('B002863BIW', 0),
#               ('B00M08ZKNC', 0),
#               ('B01133LB1E', 0)],
#              'A215DJOA5P62J4': [('B000JJO058', 0),
#               ('B0000CFH7B', 0),
#               ('B0000VMB38', 0),
#               ('B002DYJ214', 0),
#               ('B00LHFNWA2', 0),
#               ('B0010AP7GQ', 0),
#               ('B005CUK20Q', 0)],
#              'A1EN93BVDOBY9R': [('B000YT7THY', 0),
#               ('B002MGM5EE', 0),
#               ('B0000CFH7B', 0),
#               ('B001940AJC', 0),
#               ('B0008JGW96', 0),
#               ('B0054TWQ3Q', 0),
#               ('B001F3FDOY', 0),
#               ('B001F3HD06', 0),
#               ('B00CIW2KF6', 0),
#               ('B00250UDYQ', 0),
#               ('B000XK4AE4', 0),
#               ('B000Z93FQC', 0),
#               ('B001EXR53C', 0),
#               ('B006P9XEW6', 0),
#               ('B00712FT92', 0),
#               ('B000EDI2N0', 0),
#               ('B001ZGD7JY', 0),
#               ('B00AYQB9DC', 0)],
#              'AFZQJGJ7GJ0MB': [('B0000CFH7B', 0),
#               ('B004KZGUEG', 0),
#               ('B004S8CMVK', 0),
#               ('B0052XRMJ2', 0),
#               ('B0057RHE28', 0),
#               ('B003V8Y5F4', 0),
#               ('B0052XT72M', 0),
#               ('B01G36SNYE', 0),
#               ('B0009F3SC8', 0),
#               ('B0009F3QKM', 0),
#               ('B000CONMBS', 0),
#               ('B00G5I4UCU', 0),
#               ('B00GFRO47C', 0),
#               ('B000F4ET3U', 0)],
#              'A1QTAGI15XNIQT': [('B00LQKULU2', 0),
#               ('B002PNWU5I', 0),
#               ('B0000CFH7B', 0),
#               ('B003MZAO1U', 0),
#               ('B00J8SJ6O6', 0)],
#              'A9DIFAUDTQQE1': [('B0000CFH7B', 0),
#               ('B005SWLWN4', 0),
#               ('B000WV0RW8', 0),
#               ('B00JEL3AXU', 0),
#               ('B00IDCFXG8', 0),
#               ('B000EDG598', 0),
#               ('B00473RWXY', 0),
#               ('B004K0862K', 0)],
#              'A8O12DCHIADYU': [('B000VTBFIG', 0),
#               ('B000HDMXGO', 0),
#               ('B0079P0QNA', 0),
#               ('B0000CFH7B', 0),
#               ('B00H8YGOMO', 0)],
#              'A33MJGWFHQ613L': [('B0000CFH7B', 0),
#               ('B0012DMI1S', 0),
#               ('B002PO09MS', 0),
#               ('B00A8PYXMS', 0)],
#              'A23R57O89PFISS': [('B0000CFH7B', 0),
#               ('B004CH4PZ8', 0),
#               ('B007KCTLQ0', 0),
#               ('B007KCQFM8', 0),
#               ('B000KJVIOI', 0),
#               ('B004SK4KIG', 0),
#               ('B011B45FZS', 0)],
#              'AOML345I5BMOX': [('B002QJ5SM8', 0),
#               ('B00534SXGG', 0),
#               ('B008I7EIQY', 0),
#               ('B0000CFMXV', 0),
#               ('B003KK42V0', 0),
#               ('B003YJ14QS', 0),
#               ('B00D6LXNGI', 0),
#               ('B00MHSRUPQ', 0)],
#              'A37EOLAE5SITDL': [('B0000CFMXV', 0),
#               ('B005CW3MB0', 0),
#               ('B005R7PQGY', 0),
#               ('B00A380YYQ', 0),
#               ('B0009VFDEI', 37065600),
#               ('B000EUD6AM', 0),
#               ('B00117YT4Y', 12355200.0),
#               ('B003YKP1Y8', 37065600),
#               ('B000FK7G20', 0),
#               ('B0014EQHG2', 0),
#               ('B014LPLPOE', 0),
#               ('B00UL9W0TE', 0),
#               ('B0064Y4ZKM', 0)],
#              'A2UT60M6WEQMT9': [('B001SATPQG', 0),
#               ('B001Z2O0T4', 0),
#               ('B000FD93DC', 0),
#               ('B0000CFMU7', 0),
#               ('B000ZEIR6U', 0),
#               ('B0012A8GVC', 0),
#               ('B003DU924E', 0)],
#              'A28LRTOW3H8K00': [('B001PQREMK', 0),
#               ('B000AY9VCE', 0),
#               ('B001M0A8XQ', 0),
#               ('B004P7T7ZS', 0),
#               ('B0000CFMU7', 0)],
#              'A3CIO3L47ZVF0T': [('B00ZKUL67G', 0),
#               ('B0007LXU0Y', 0),
#               ('B000GZSDZI', 0),
#               ('B001795P3K', 0),
#               ('B00N0X0TF0', 0),
#               ('B000KEJMS2', 0),
#               ('B004VLVK58', 0),
#               ('B00I3K37FO', 0),
#               ('B001AQTUK4', 0),
#               ('B00JPT9BFW', 0),
#               ('B01476P46M', 0),
#               ('B00F94YP8A', 0),
#               ('B004X8TJP2', 0),
#               ('B014X2D8DQ', 0),
#               ('B0000CFMU7', 0)],
#              'A10XHF2ZPXR5ES': [('B00IVT3LVM', 0),
#               ('B001EO6ESS', 0),
#               ('B00DTVBEY8', 0),
#               ('B001ELL4ZY', 0),
#               ('B00AR0ZZ62', 0),
#               ('B0000CFMU7', 0),
#               ('B005N2VCLQ', 0),
#               ('B01HGBAFNC', 0)],
#              'A31P9X72PXSKK0': [('B0007LXU0Y', 0),
#               ('B003DU924E', 0),
#               ('B00146IAG0', 0),
#               ('B00CVY459K', 0),
#               ('B0000CFMU7', 0)],
#              'A2KBKRA6S1K586': [('B00OEEPFA8', 0),
#               ('B000KHMWQS', 0),
#               ('B000WLJICI', 0),
#               ('B000WS1KI6', 0),
#               ('B004ZKXLXO', 0),
#               ('B000GW0U9I', 0),
#               ('B000MDAT9C', 0),
#               ('B007RAMD3S', 0),
#               ('B00AOMO1CW', 0),
#               ('B00E0N2SEO', 0),
#               ('B00WFEGVSY', 0),
#               ('B003O6E5QC', 0),
#               ('B00DY0B2X2', 0),
#               ('B00DY0AYO0', 0),
#               ('B0012BSBYS', 0),
#               ('B00269T9JQ', 0),
#               ('B0005ZXX1S', 0),
#               ('B000F4DK9Y', 0),
#               ('B008RYNJ9A', 0),
#               ('B005QQ1L10', 0),
#               ('B00BC3WVNS', 0),
#               ('B0039QQX8A', 0),
#               ('B00WUVK4DU', 0),
#               ('B0000CFMU7', 0)],
#              'A3KB49T9FRLL73': [('B000XR5MLW', 0),
#               ('B00BSVQE1O', 0),
#               ('B002VJKKS0', 6048000),
#               ('B000BB4BTO', 0),
#               ('B00U0Y2B4E', 0),
#               ('B000FCYGBW', 0),
#               ('B0000CFMU7', 0),
#               ('B00QFPP6YE', 0)],
#              'AN3CTP99IDTJL': [('B00BUKL666', 0),
#               ('B00D3M2QP4', 0),
#               ('B008QMX2SG', 0),
#               ('B00R7PWK7W', 0),
#               ('B0000CFMU7', 0)],
#              'A3815AE1FRZEIE': [('B005VOOOQQ', 0),
#               ('B000ED7M3Q', 0),
#               ('B004391DK0', 0),
#               ('B0078DQLAU', 0),
#               ('B00286KM2A', 0),
#               ('B0000CFMU7', 0),
#               ('B006MW5DGG', 0),
#               ('B004LKVRKM', 0),
#               ('B0082313JE', 0)],
#              'A2XY14STO2FXKS': [('B00BJN7EDS', 0),
#               ('B00O647RR0', 0),
#               ('B014B1VXTK', 0),
#               ('B00F9WYIC0', 0),
#               ('B0000CFMU7', 0),
#               ('B000WY96Q8', 0)],
#              'A2LPF31O1S7DNI': [('B0000CFMU7', 0),
#               ('B01CQ3K21U', 0),
#               ('B001EPQTD2', 0),
#               ('B00B0H1GAU', 0),
#               ('B017Y9HNY0', 0)],
#              'A2FEM9GRK98IPN': [('B00028MOQS', 0),
#               ('B001HTJ2BQ', 0),
#               ('B005GTTTBQ', 0),
#               ('B00CQAVSLM', 0),
#               ('B00E0WB292', 0),
#               ('B00FPSTKEO', 0),
#               ('B00GRY33AC', 0),
#               ('B00I8V8PPK', 0),
#               ('B010FBXO38', 0),
#               ('B01DQ14Z64', 0),
#               ('B0000CFMU7', 0),
#               ('B00EEN74L2', 0),
#               ('B00GN065A0', 0),
#               ('B015K8V0I2', 0),
#               ('B01965DY48', 0),
#               ('B00AF7XMYY', 0),
#               ('B00MA84WKY', 0),
#               ('B01133LB1E', 0),
#               ('B001D3NXVQ', 0),
#               ('B00HYL4HK2', 0),
#               ('B00L5L655W', 0),
#               ('B00KHAIBQI', 0)],
#              'A2QQNGLXQ1DK6N': [('B0074YT37Q', 0),
#               ('B008P731LK', 0),
#               ('B008T9LX3C', 0),
#               ('B0000CFMU7', 0),
#               ('B0099XI58S', 0)],
#              'A2RID4JUGL48KB': [('B00KSIE39I', 0),
#               ('B0000CFMU7', 0),
#               ('B001EXR53C', 0),
#               ('B0042YATG0', 0),
#               ('B000FRUNL4', 0)],
#              'A1KMAW13FUUNCA': [('B000GFYRK8', 0),
#               ('B0000EYQ1U', 0),
#               ('B0018AXEWC', 0),
#               ('B001EO5Y8E', 0),
#               ('B0000CFMU7', 0),
#               ('B00BG41RB0', 0),
#               ('B01GLLZJFM', 0),
#               ('B000AYGXDO', 0)],
#              'A27RYQYVVH5H2A': [('B01498CFLK', 0),
#               ('B014E4FD8Q', 0),
#               ('B012YAV43A', 0),
#               ('B005P0N83Q', 0),
#               ('B00JJGN14S', 0),
#               ('B00QU781RG', 0),
#               ('B005CD3B8S', 0),
#               ('B0000CFMU7', 0),
#               ('B00028MO04', 0),
#               ('B0151VS96E', 0),
#               ('B00IN57S2W', 0),
#               ('B00IJGLAME', 0),
#               ('B0099XPG94', 0),
#               ('B000EA2DA6', 0)],
#              'A2PLA73FHDAEZ4': [('B00124TTG4', 0),
#               ('B0000CFMU7', 0),
#               ('B00PUSOCTW', 0),
#               ('B00PT66JYQ', 0)],
#              ...})

# %%
from collections import Counter
counter=Counter(df['asin'].tolist())

# %%
# Counter 객체에서 값(value)이 1 이상인 키(key)들을 추출
filtered_keys = [key for key, value in counter.items() if value > 1]

# 값이 1 이상인 키들에 해당하는 값(value)들을 데이터프레임의 열(column)로 변환
values_list = [counter[key] for key in filtered_keys]
df = pd.DataFrame(values_list, columns=['count'])

# 데이터프레임의 describe() 메서드를 사용하여 통계 정보 출력
description = df.describe()
description
# Out:
#               count
# count  41306.000000
# mean      27.692006
# std       95.937762
# min        2.000000
# 25%        6.000000
# 50%       10.000000
# 75%       22.000000
# max     7387.000000

# %% [markdown]
# # 데이터 확인

# %%
import gzip
import pickle as pkl
from collections import defaultdict
import numpy as np
import pandas as pd
import json
import random

def parse(path):
    with gzip.open(path, 'rb') as f:
        for line in f:
            yield json.loads(line)

def get_items_meta(meta_path, categories_used='all'):
    # item2price = {}
    item2category = {}
    item2brand = {}

    if categories_used == 'all':
        for l in parse(meta_path):

            asin = l['asin']
            item2category[asin] = l['category']
            # item2price[asin] = l['price'][1:] if 'price' in l else 0.0
            item2brand[asin] = l['brand'] if 'brand' in l else ''
    else:
        for l in parse(meta_path):
            asin = l['asin']
            item2category[asin] = l['category'][0] if l['category'] else ''  # 첫 번째 카테고리만 사용
            # item2price[asin] = l['price'][1:] if 'price' in l else 0.0
            item2brand[asin] = l['brand'] if 'brand' in l else ''

    items_meta = {
        # 'item2price': item2price,
        'item2category': item2category,
        'item2brand': item2brand
    }
    return items_meta

# %%
meta_path='data/Grocery_and_Gourmet_Food/meta_Grocery_and_Gourmet_Food.json.gz'
reviews_path='data/Grocery_and_Gourmet_Food/Grocery_and_Gourmet_Food_5.json.gz'
categories_used='all'
user2id = {'[PAD]': 0}
item2id = {'[PAD]': 0}
items_map = {
    # 'item2price': {},
    'item2category': {},
    'item2brand': {}
}
user_reviews = defaultdict(list)
action_times = []
items_meta = get_items_meta(meta_path, categories_used)

for l in parse(reviews_path):
    if l['reviewerID'] not in user2id:
        user2id[l['reviewerID']] = len(user2id)
    action_times.append(l['unixReviewTime'])
    user_reviews[l['reviewerID']].append([l['asin'], l['unixReviewTime']])

for u in user_reviews:
    user_reviews[u].sort(key=lambda x: x[1])
    for item, time in user_reviews[u]:
        if item not in item2id:
            item2id[item] = len(item2id)
item2_id_list=[] 
for item in item2id.keys():
    item2_id_list.append(item)  # review item 41321

items_meta_itemid_list=[]
not_match_item_id=[]
items_meta_itemid_list=set(list(items_meta['item2brand'].keys())) # meta data itemid

for item in item2_id_list:
    if item not in items_meta_itemid_list:
            not_match_item_id.append(item)# meta item
not_match_item_id.remove('[PAD]')  # 40

#change itemid: 41321->41281

remove_unmatch_item_item2id={}
for itemid in item2id:
    if itemid not in not_match_item_id: 
        if itemid not in remove_unmatch_item_item2id.keys(): # remove duplicate & first appear
            remove_unmatch_item_item2id[itemid] = len(remove_unmatch_item_item2id)

item2id=remove_unmatch_item_item2id

# %%
len(item2id)
# Out:
# 41281

# %% [markdown]
# ### 5번 이상 구매된 item 필터링

# %%
item_purchase_counts = defaultdict(int)

# 각 유저의 구매 기록을 사용하여 아이템별 구매 횟수를 계산
for user, interactions_list in user_reviews.items():
    for item, action_time in interactions_list:
        if item in item2id:  # item2id에 존재하는 아이템만 고려
            item_purchase_counts[item] += 1

# # 5번 이상 구매된 아이템 필터링
# items_over_5_purchases = {item: count for item, count in item_purchase_counts.items() if count >= 5}

# %%
len(item_purchase_counts)
# Out:
# 41280

# %%
user_over_5_item_purchases = {}

for user, interactions_list in user_reviews.items():
    item_count = sum(1 for item, action_time in interactions_list if item in item_purchase_counts)
    if item_count >= 5:
        user_over_5_item_purchases[user] = interactions_list

# %%
len(user_over_5_item_purchases)
# Out:
# 127364
